# %%
from ILQGController import *

# %%
st = ToCartesian(np.array([pi/4,pi/2]))
tg = ToCartesian(np.array([pi/2,pi/4]))

ILQG(Duration = 1,start = st,targets=tg )
# Out:
# (array([ -2.12132034,  -2.12132034,  -2.12132034,  -2.13783786,
#          -2.18181654,  -2.26019151,  -2.37701542,  -2.53427263,
#          -2.73247023,  -2.97106866,  -3.24879637,  -3.5638804 ,
#          -3.91421573,  -4.29748979,  -4.71127386,  -5.15309   ,
#          -5.62045955,  -6.11093758,  -6.6221367 ,  -7.15174232,
#          -7.6975213 ,  -8.25732528,  -8.82908964,  -9.41082911,
#         -10.00063063, -10.59664417, -11.19707219, -11.80015823,
#         -12.40417531, -13.00741458, -13.60817488, -14.20475354,
#         -14.79543904, -15.37850584, -15.9522118 , -16.5147985 ,
#         -17.06449474, -17.5995235 , -18.1181125 , -18.61850852,
#         -19.09899558, -19.55791698, -19.99370111, -20.40489069,
#         -20.79017505, -21.1484245 , -21.47872578, -21.78041667,
#         -22.05311773, -22.2967583 , -22.51159356, -22.69820948,
#         -22.85751279, -22.99070417, -23.09923577, -23.18475731,
#         -23.24906086, -23.29404104, -23.32169519, -23.33419599]),
# ...

# %%
st = np.array([0,40])
d = 15
for i in np.linspace(0,2*pi,9)[:8]:
    tg = st+np.array([cos(i)*d,sin(i)*d])
    ILQG(Duration = .6,start = st,targets=tg )

# %%
st = ToCartesian(np.array([pi/4,pi/2]))
tg = ToCartesian(np.array([pi/2,pi/4]))

ILQG(Duration = 1,start = st,targets=tg )
