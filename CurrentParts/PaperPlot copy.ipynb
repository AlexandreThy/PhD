# %%
import os
os.chdir('..')
import sys
from Controllers.FL import *
from Controllers.ILQG import *
from Controllers.LQGControllers import *
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib import gridspec

# %%
NUM_SIM = 30
XST = 0
YST = 45
st = [XST,YST]
MovementTime = .4
NumIteration = 40
Time = np.linspace(0,MovementTime*1000,NumIteration)
MN = 1e-3
WP = 100
WV = .05
WR = .1

NUM_SIM = 100
DURATIONS = [.3,.4,.5,.6,.7,.8,.9,1]
DURATIONS_ms = [300,400,500,600,700,800,900,1000]
colors = ["#009E73","#0072B2","#E69F00"]
legend = ["ILQG","FL","DLQG"]

def Cost_function(x,u,w1 = 100,w2 = .05,r = .1,tg = [0,0] ):
    target1,target2 = compute_angles_from_cartesian(tg[0],tg[1])
    thetas,thetae,omegas,omegae = x[-1,:4]
    
    return w1*(thetas-target1)**2 + w1*(thetae-target2)**2 + w2*(omegas**2+omegae**2)+ np.sum(u*u) * r

def Compute_Cartesian_Speed(X, Y, dt):
    V = np.zeros(X.shape)
    Vx = np.diff(X) / dt
    Vy = np.diff(Y) / dt
    V[1:] = np.sqrt(Vx * Vx + Vy * Vy)
    return V

# %%
NUM_SIM = 15

plt.figure(figsize = (8,8))
trajectories = np.zeros((NUM_SIM,8,NumIteration+1,2))

for num_sim in range(NUM_SIM):
    for iter,angles in enumerate(np.linspace(0,2*pi,9)[:-1]) :
        tg = [XST+cos(angles)*15,YST+sin(angles)*15]
        xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=True,motornoise_variance=MN,print_iterations=False)
        trajectories[num_sim,iter] = np.array([xILQG,yILQG]).T

        if num_sim <= 15 : plt.plot(xILQG,yILQG,color = "#009E73",linewidth = 1,label = "ILQG")
        plt.plot([tg[0]],[tg[1]],marker = "s",markersize = 25,markeredgecolor = "grey",markerfacecolor='white',zorder = 0,markeredgewidth = 5)
plt.axis("equal")
ax = plt.gca()
plt.plot([XST],[YST],marker = "o",markersize = 25,markeredgecolor = "grey",markerfacecolor='white',zorder = 0,markeredgewidth = 5)
ax.axis("off")
plt.savefig("ILQG_Centerout.svg",dpi = 300)
plt.show()
plt.figure(figsize = (8,8))
for iter,angles in enumerate(np.linspace(0,2*pi,9)[:-1]) :
    tg = [XST+cos(angles)*15,YST+sin(angles)*15]
    plt.plot(np.mean(trajectories[:,iter,:,0],axis = 0),np.mean(trajectories[:,iter,:,1],axis = 0),color = "#009E73",linewidth = 3,label = "ILQG")
    plt.plot([tg[0]],[tg[1]],marker = "s",markersize = 25,markeredgecolor = "grey",markerfacecolor='white',zorder = 0,markeredgewidth = 5)

plt.axis("equal")
ax = plt.gca()
plt.plot([XST],[YST],marker = "o",markersize = 25,markeredgecolor = "grey",markerfacecolor='white',zorder = 0,markeredgewidth = 5)
ax.axis("off")
# Out:
# (np.float64(-16.5),
#  np.float64(16.5),
#  np.float64(28.499619921918104),
#  np.float64(61.507981639719816))

# %%
NUM_SIM = 15

MovementTime = .4
NumIteration = 80
Cost_value = np.zeros((NUM_SIM,9,3))
Commands = np.zeros((NUM_SIM,8,3,NumIteration,6))
st = [0,40]
WP = 20000
WV =  1
WR = .1
MN = 5e-4
NOISE = True
trajectories = np.zeros((NUM_SIM,8,NumIteration+1,2))

for num_sim in range(NUM_SIM):

    for iter,angles in enumerate(np.linspace(0,2*pi,9)[:-1]) :

        tg = [st[0]+cos(angles)*15,st[1]+sin(angles)*15]
        xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=1e-8,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True,FF = False)
        trajectories[num_sim,iter] = np.array([xFL,yFL]).T
        if num_sim <= 15 : plt.plot(xFL,yFL,color = "#0072B2",linewidth = 1,label = "FL")
        plt.plot([tg[0]],[tg[1]],marker = "s",markersize = 25,markeredgecolor = "grey",markerfacecolor='white',zorder = 0,markeredgewidth = 5)

plt.axis("equal")
ax = plt.gca()
plt.plot([st[0]],[st[1]],marker = "o",markersize = 25,markeredgecolor = "grey",markerfacecolor='white',zorder = 0,markeredgewidth = 5)
ax.axis("off")
plt.savefig("FL_Centerout.svg",dpi = 300)
plt.show()
plt.figure(figsize = (8,8))
plt.plot([st[0]],[st[1]],marker = "o",markersize = 25,markeredgecolor = "grey",markerfacecolor='white',zorder = 0,markeredgewidth = 5)
for iter,angles in enumerate(np.linspace(0,2*pi,9)[:-1]) :
    
    tg = [st[0]+cos(angles)*15,st[1]+sin(angles)*15]
    plt.plot(np.mean(trajectories[:,iter,:,0],axis = 0),np.mean(trajectories[:,iter,:,1],axis = 0),color = "#0072B2",linewidth = 3,label = "FL")
    plt.plot([tg[0]],[tg[1]],marker = "s",markersize = 25,markeredgecolor = "grey",markerfacecolor='white',zorder = 0,markeredgewidth = 5)
    
plt.axis("equal")
ax = plt.gca()
ax.axis("off")
# Out:
# (np.float64(-16.500250235905018),
#  np.float64(16.505254954005338),
#  np.float64(23.499468693148746),
#  np.float64(56.51115744387632))

# %%
plt.figure(figsize = (8,8))
trajectories = np.zeros((NUM_SIM,8,NumIteration+1,2))
XST = 0
YST = 45
st = [XST,YST]
WP = 20000
WV = 1
WR = .1
for num_sim in range(NUM_SIM):

    for iter,angles in enumerate(np.linspace(0,2*pi,9)[:-1]) :

        tg = [XST+cos(angles)*15,YST+sin(angles)*15]
        xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = WP,w2 = WP,w3=WV,w4=WV,Duration=MovementTime,r1 = WR,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True)
        trajectories[num_sim,iter] = np.array([xLQG,yLQG]).T
        if num_sim <= 15 : plt.plot(xLQG,yLQG,color = "#E69F00",linewidth = 1,label = "DLQG")
        plt.plot([tg[0]],[tg[1]],marker = "s",markersize = 25,markeredgecolor = "grey",markerfacecolor='white',zorder = 0,markeredgewidth = 5)

plt.axis("equal")
ax = plt.gca()
plt.plot([XST],[YST],marker = "o",markersize = 25,markeredgecolor = "grey",markerfacecolor='white',zorder = 0,markeredgewidth = 5)
ax.axis("off")
#plt.savefig("DLQG_Centerout.svg",dpi = 300)
plt.show()
plt.figure(figsize = (8,8))
plt.plot([XST],[YST],marker = "o",markersize = 25,markeredgecolor = "grey",markerfacecolor='white',zorder = 0,markeredgewidth = 5)
for iter,angles in enumerate(np.linspace(0,2*pi,9)[:-1]) :
    
    tg = [XST+cos(angles)*15,YST+sin(angles)*15]
    plt.plot(np.mean(trajectories[:,iter,:,0],axis = 0),np.mean(trajectories[:,iter,:,1],axis = 0),color = "#E69F00",linewidth = 3,label = "DLQG")
    plt.plot([tg[0]],[tg[1]],marker = "s",markersize = 25,markeredgecolor = "grey",markerfacecolor='white',zorder = 0,markeredgewidth = 5)
    
plt.axis("equal")
ax = plt.gca()
ax.axis("off")
# Out:
# (np.float64(-16.72004768496115),
#  np.float64(16.650445868716364),
#  np.float64(28.5),
#  np.float64(61.5))

# %%
NUM_SIM = 100

MovementTime = .4
NumIteration = 80
fig,ax = plt.subplots(figsize = (8,8),subplot_kw={'projection': 'polar'})
Cost_value = np.zeros((NUM_SIM,9,3))
Commands = np.zeros((NUM_SIM,8,3,NumIteration,6))
st = [0,40]
WP = 20000
WV =  1
WR = .1
MN = 2e-4
NOISE = True
def Cost_function(x,u,w1 = WP,w2 = WV,r = WR,tg = [0,0] ):
    target1,target2 = compute_angles_from_cartesian(tg[0],tg[1])
    thetas,thetae,omegas,omegae = x[-1,:4]
    
    return w1*(thetas-target1)**2 + w1*(thetae-target2)**2 + w2*(omegas**2+omegae**2)+ np.sum(u*u) * r

for num_sim in range(NUM_SIM):

    for iter,angles in enumerate(np.linspace(0,2*pi,9)[:-1]) :
        tg = [st[0]+cos(angles)*15,st[1]+sin(angles)*15]
        xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=NOISE,print_iterations=False,motornoise_variance=MN)
        xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=1e-6,FF=False,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=NOISE,motornoise_variance=MN)
        xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = WP,w2 = WP,w3=WV,w4=WV,Duration=MovementTime,r1 = WR,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=NOISE,motornoise_variance=MN) 
        Commands[num_sim,iter] = np.array([uILQG,uFL,uDLQG])
        Cost_value[num_sim,iter] = np.array([Cost_function(zilqg,uILQG,tg = tg),Cost_function(xfl,uFL,tg = tg),Cost_function(z.T,uDLQG,tg = tg)])

Cost_value = np.mean(Cost_value,axis = 0)
Commands = np.mean(Commands,axis = 0)
colors = ["#009E73","#0072B2","#E69F00"]
legend = ["ILQG","FL","DLQG"]
Cost_value[8] = Cost_value[0]

angles = np.linspace(0, 2*np.pi, 9)
for i in range(3):
    ax.scatter(angles, Cost_value[:,i], color=colors[i], s = 20, zorder = 10)
    ax.plot(angles, Cost_value[:,i], color=colors[i], linewidth=2,linestyle = "--",label = legend[i])
ax.set_xticklabels([])
np.savez("Costdatahighdt.npz", my_array=Cost_value)

plt.savefig("CostfuncContourhighdt.svg",dpi = 300)
plt.show()
# Out:
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:469: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[k] = Q[k] + A[k].T @ S[k + 1] @ A[k] - G.T @ Hinv @ G
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:470: ComplexWarning: Casting complex values to real discards the imaginary part
#   sbold[k] = qbold[k] + A[k].T @ sbold[k + 1] - G.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:471: ComplexWarning: Casting complex values to real discards the imaginary part
#   s[k] = q[k] + s[k + 1] + 0.5 * temp3 - 0.5 * gbold.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:473: ComplexWarning: Casting complex values to real discards the imaginary part
#   l[k] = -Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:474: ComplexWarning: Casting complex values to real discards the imaginary part
#   L[k] = -Hinv @ G

# %%
NUM_SIM = 100

MovementTime = .4
NumIteration = 40
fig,ax = plt.subplots(figsize = (8,8),subplot_kw={'projection': 'polar'})
Cost_value = np.zeros((NUM_SIM,9,3))
Commands = np.zeros((NUM_SIM,8,3,NumIteration,6))
st = [0,40]

WP = 20000
WV = 1
WR = .5

def Cost_function(x,u,w1 = WP,w2 = WV,r = WR,tg = [0,0] ):
    target1,target2 = compute_angles_from_cartesian(tg[0],tg[1])
    thetas,thetae,omegas,omegae = x[-1,:4]
    
    return w1*(thetas-target1)**2 + w1*(thetae-target2)**2 + w2*(omegas**2+omegae**2)+ np.sum(u*u) * r

for num_sim in range(NUM_SIM):

    for iter,angles in enumerate(np.linspace(0,2*pi,9)[:-1]) :
        tg = [st[0]+cos(angles)*15,st[1]+sin(angles)*15]
        xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False,motornoise_variance=5e-4)
        xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=1e-8,FF=False,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True,motornoise_variance=5e-4)
        xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = WP,w2 = WP,w3=WV,w4=WV,Duration=MovementTime,r1 = WR,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True,motornoise_variance=5e-4) 
        Commands[num_sim,iter] = np.array([uILQG,uFL,uDLQG])
        Cost_value[num_sim,iter] = np.array([Cost_function(zilqg,uILQG,tg = tg),Cost_function(xfl,uFL,tg = tg),Cost_function(z.T,uDLQG,tg = tg)])

Cost_value = np.mean(Cost_value,axis = 0)
Commands = np.mean(Commands,axis = 0)
colors = ["#009E73","#0072B2","#E69F00"]
legend = ["ILQG","FL","DLQG"]
Cost_value[8] = Cost_value[0]

angles = np.linspace(0, 2*np.pi, 9)
for i in range(3):
    ax.scatter(angles, Cost_value[:,i], color=colors[i], s = 20, zorder = 10)
    ax.plot(angles, Cost_value[:,i], color=colors[i], linewidth=2,linestyle = "--",label = legend[i])
ax.set_xticklabels([])
plt.savefig("CostfuncContour2.svg",dpi = 300)
plt.show()

# %%
NUM_SIM = 1

MovementTime = .4
NumIteration = 40
fig,ax = plt.subplots(figsize = (8,8),subplot_kw={'projection': 'polar'})
Cost_value = np.zeros((NUM_SIM,9,3))
Commands = np.zeros((NUM_SIM,8,3,NumIteration,6))
st = [0,40]

WP = 20000
WV = 1
WR = .5

def Cost_function(x,u,w1 = WP,w2 = WV,r = WR,tg = [0,0] ):
    target1,target2 = compute_angles_from_cartesian(tg[0],tg[1])
    thetas,thetae,omegas,omegae = x[-1,:4]
    
    return w1*(thetas-target1)**2 + w1*(thetae-target2)**2 + w2*(omegas**2+omegae**2)+ np.sum(u*u) * r

for num_sim in range(NUM_SIM):

    for iter,angles in enumerate(np.linspace(0,2*pi,9)[:-1]) :
        tg = [st[0]+cos(angles)*15,st[1]+sin(angles)*15]
        xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=False,print_iterations=False,motornoise_variance=MN)
        xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=1e-8,FF=False,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=False,motornoise_variance=MN)
        xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = WP,w2 = WP,w3=WV,w4=WV,Duration=MovementTime,r1 = WR,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=False,motornoise_variance=MN) 
        Commands[num_sim,iter] = np.array([uILQG,uFL,uDLQG])
        Cost_value[num_sim,iter] = np.array([Cost_function(zilqg,uILQG,tg = tg),Cost_function(xfl,uFL,tg = tg),Cost_function(z.T,uDLQG,tg = tg)])

Cost_value = np.mean(Cost_value,axis = 0)
Commands = np.mean(Commands,axis = 0)
colors = ["#009E73","#0072B2","#E69F00"]
legend = ["ILQG","FL","DLQG"]
Cost_value[8] = Cost_value[0]

angles = np.linspace(0, 2*np.pi, 9)
for i in range(3):
    ax.scatter(angles, Cost_value[:,i], color=colors[i], s = 20, zorder = 10)
    ax.plot(angles, Cost_value[:,i], color=colors[i], linewidth=2,linestyle = "--",label = legend[i])
ax.set_xticklabels([])
#plt.savefig("CostfuncContour2.svg",dpi = 300)
plt.show()
# Out:
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:469: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[k] = Q[k] + A[k].T @ S[k + 1] @ A[k] - G.T @ Hinv @ G
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:470: ComplexWarning: Casting complex values to real discards the imaginary part
#   sbold[k] = qbold[k] + A[k].T @ sbold[k + 1] - G.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:471: ComplexWarning: Casting complex values to real discards the imaginary part
#   s[k] = q[k] + s[k + 1] + 0.5 * temp3 - 0.5 * gbold.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:473: ComplexWarning: Casting complex values to real discards the imaginary part
#   l[k] = -Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:474: ComplexWarning: Casting complex values to real discards the imaginary part
#   L[k] = -Hinv @ G

# %%
NUM_SIM = 100

MovementTime = .4
NumIteration = 40
fig,ax = plt.subplots(figsize = (8,8),subplot_kw={'projection': 'polar'})
Cost_value = np.zeros((NUM_SIM,9,3))
Commands = np.zeros((NUM_SIM,8,3,NumIteration,6))
st = [0,35]

WP = 20000
WV = 1
WR = .02

def Cost_function(x,u,w1 = WP,w2 = WV,r = WR,tg = [0,0] ):
    target1,target2 = compute_angles_from_cartesian(tg[0],tg[1])
    thetas,thetae,omegas,omegae = x[-1,:4]
    
    return w1*(thetas-target1)**2 + w1*(thetae-target2)**2 + w2*(omegas**2+omegae**2)+ np.sum(u*u) * r

for num_sim in range(NUM_SIM):

    for iter,angles in enumerate(np.linspace(0,2*pi,9)[:-1]) :
        tg = [st[0]+cos(angles)*15,st[1]+sin(angles)*15]
        xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False)
        xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=1e-8,FF=False,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True)
        xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = WP,w2 = WP,w3=WV,w4=WV,Duration=MovementTime,r1 = WR,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True) 
        Commands[num_sim,iter] = np.array([uILQG,uFL,uDLQG])
        Cost_value[num_sim,iter] = np.array([Cost_function(zilqg,uILQG,tg = tg),Cost_function(xfl,uFL,tg = tg),Cost_function(z.T,uDLQG,tg = tg)])

Cost_value = np.mean(Cost_value,axis = 0)
Commands = np.mean(Commands,axis = 0)
colors = ["#009E73","#0072B2","#E69F00"]
legend = ["ILQG","FL","DLQG"]
Cost_value[8] = Cost_value[0]

angles = np.linspace(0, 2*np.pi, 9)
for i in range(3):
    ax.scatter(angles, Cost_value[:,i], color=colors[i], s = 20, zorder = 10)
    ax.plot(angles, Cost_value[:,i], color=colors[i], linewidth=2,linestyle = "--",label = legend[i])
ax.set_xticklabels([])
plt.savefig("CostfuncContour2.svg",dpi = 300)
plt.show()
# Out:
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:469: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[k] = Q[k] + A[k].T @ S[k + 1] @ A[k] - G.T @ Hinv @ G
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:470: ComplexWarning: Casting complex values to real discards the imaginary part
#   sbold[k] = qbold[k] + A[k].T @ sbold[k + 1] - G.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:471: ComplexWarning: Casting complex values to real discards the imaginary part
#   s[k] = q[k] + s[k + 1] + 0.5 * temp3 - 0.5 * gbold.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:473: ComplexWarning: Casting complex values to real discards the imaginary part
#   l[k] = -Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:474: ComplexWarning: Casting complex values to real discards the imaginary part
#   L[k] = -Hinv @ G

# %%
NUM_SIM = 100

MovementTime = .4
NumIteration = 40
fig,ax = plt.subplots(figsize = (8,8),subplot_kw={'projection': 'polar'})
Cost_value = np.zeros((NUM_SIM,9,3))
Commands = np.zeros((NUM_SIM,8,3,NumIteration,6))
st = [0,45]

for num_sim in range(NUM_SIM):

    for iter,angles in enumerate(np.linspace(0,2*pi,9)[:-1]) :
        tg = [cos(angles)*15,45+sin(angles)*15]
        xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,100,.05,.1,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False)
        xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=100,w2=100,w3=.05,w4=.05,r=1e-8,FF=False,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True)
        xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = 100,w2 = 100,w3=.05,w4=.05,Duration=MovementTime,r1 = .1,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True) 
        Commands[num_sim,iter] = np.array([uILQG,uFL,uDLQG])
        Cost_value[num_sim,iter] = np.array([Cost_function(zilqg,uILQG,tg = tg),Cost_function(xfl,uFL,tg = tg),Cost_function(z.T,uDLQG,tg = tg)])

Cost_value = np.mean(Cost_value,axis = 0)
Commands = np.mean(Commands,axis = 0)
colors = ["#009E73","#0072B2","#E69F00"]
legend = ["ILQG","FL","DLQG"]
Cost_value[8] = Cost_value[0]

angles = np.linspace(0, 2*np.pi, 9)
for i in range(3):
    ax.scatter(angles, Cost_value[:,i], color=colors[i], s = 20, zorder = 10)
    ax.plot(angles, Cost_value[:,i], color=colors[i], linewidth=2,linestyle = "--",label = legend[i])

ax.set_xticklabels([])
ax.set_yticks([.05,.1,.15])
np.savez("Costdata.npz", my_array=Cost_value)
plt.savefig("CostfuncContour.svg",dpi = 300)
plt.show()
# Out:
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:469: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[k] = Q[k] + A[k].T @ S[k + 1] @ A[k] - G.T @ Hinv @ G
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:470: ComplexWarning: Casting complex values to real discards the imaginary part
#   sbold[k] = qbold[k] + A[k].T @ sbold[k + 1] - G.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:471: ComplexWarning: Casting complex values to real discards the imaginary part
#   s[k] = q[k] + s[k + 1] + 0.5 * temp3 - 0.5 * gbold.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:473: ComplexWarning: Casting complex values to real discards the imaginary part
#   l[k] = -Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:474: ComplexWarning: Casting complex values to real discards the imaginary part
#   L[k] = -Hinv @ G

# %%
fig,ax = plt.subplots(2,1,figsize = (4,8))
NUM_SIM = 100
NumIteration = 40
MovementTime = .4
Velocities = np.zeros((NUM_SIM,8,3,NumIteration+1,2))

for num_sim in range(NUM_SIM):

    for iter,angles in enumerate(np.linspace(0,2*pi,9)[:-1]) :

        tg = [cos(angles)*15,45+sin(angles)*15]
        xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,100,.05,.1,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False)
        xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=100,w2=100,w3=.05,w4=.05,r=1e-8,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True)
        xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = 100,w2 = 100,w3=.05,w4=.05,Duration=MovementTime,r1 = .1,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True) 
        Velocities[num_sim,iter] = np.array([zilqg[:,2:4],xfl[:,2:4],z.T[:,2:4]])

legend = ["ILQG","FL","DLQG"]
Time = np.linspace(0,MovementTime,NumIteration+1)*1000
for joint in range(2):
    for target in [5,7]:
        plt.subplot(2,1,int((target-1)/3))
        ls = "-" if joint == 0 else "--"
        for controller in range(3):
            mean_vel = np.mean(Velocities[:,target,controller,:,joint],axis = 0)*180/pi
            std_vel = np.std(Velocities[:,target,controller,:,joint],axis = 0)*180/pi
            plt.plot(Time,mean_vel,color = colors[controller],linestyle = ls,linewidth = 2,label = legend[controller])
            plt.fill_between(Time,mean_vel - std_vel, mean_vel + std_vel, color=colors[controller], alpha=0.3)
        
        plt.plot([0,MovementTime*1000],[0,0],color = "grey",linestyle = "--")
        plt.yticks([-90,0,90],fontsize = 16)
        plt.xticks([0,200,400],fontsize = 16)

        delete_axis(plt.gca())

plt.savefig("Kinematiccenterout.svg",dpi = 300)
plt.show()

# %%
NUM_SIM = 10

fig,ax = plt.subplots(figsize = (8,8))
Cost_value = np.zeros((NUM_SIM,8,3,len(DURATIONS)))
for m_idx,mov_t in enumerate(DURATIONS) :
    NumIteration = int(mov_t * 100)
    for num_sim in range(NUM_SIM):
        for iter,angles in enumerate(np.linspace(0,2*pi,9)[:-1]) :
            tg = [cos(angles)*15,45+sin(angles)*15]
            xILQG,yILQG,zilqg,uILQG=simulate_ILQG(mov_t,100,.05,.1,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False)
            xFL,yFL,xfl,uFL = simulate_FL(Duration=mov_t,w1=100,w2=100,w3=.05,w4=.05,r=1e-8,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True)
        
            xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = 100,w2 = 100,w3=.05,w4=.05,Duration=mov_t,r1 = .1,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True)
            Cost_value[num_sim,iter,:,m_idx] = np.array([Cost_function(zilqg,uILQG,tg = tg),Cost_function(xfl,uFL,tg = tg),Cost_function(z.T,uDLQG,tg = tg)])

Cost_value = np.mean(Cost_value,axis = (0,1))
for i in range(3):
    plt.plot(DURATIONS_ms,Cost_value[i],color = colors[i],label = legend[i])
    plt.scatter(DURATIONS_ms,Cost_value[i],color = colors[i],s = 40)
plt.legend()
delete_axis(plt.gca(),sides = ["top","right"])
plt.yscale("log")
plt.xlabel("Movement Duration [ms]",fontsize = 14)
plt.ylabel("Average Cost Function [ms]",fontsize = 14)
plt.savefig("Movement_time.svg",dpi = 300)

# %% [markdown]
# En fait, c'est à cause du feedback qui ne s'attend pas à des déviations aussi grandes à compenser. Ceci est gérer par la matrice de covariance, qui ne voit pas ça comme du bruit musculaire car les entrées sont à 0

# %%
import os
os.chdir('..')
import sys
from Controllers.FL import *
from Controllers.ILQG import *
from Controllers.LQGControllers import *
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib import gridspec


MN = 1e-3
WP = 100
WV = .05
WR = .1


DURATIONS = [.3,.4,.5,.6,.7,.8,.9,1]
DURATIONS_ms = [300,400,500,600,700,800,900,1000]
colors = ["#009E73","#0072B2","#E69F00"]
legend = ["ILQG","FL","DLQG"]

def Cost_function(x,u,w1 = 100,w2 = .05,r = .1,tg = [0,0] ):
    target1,target2 = compute_angles_from_cartesian(tg[0],tg[1])
    thetas,thetae,omegas,omegae = x[-1,:4]
    
    return w1*(thetas-target1)**2 + w1*(thetae-target2)**2 + w2*(omegas**2+omegae**2)+ np.sum(u*u) * r * 0.01

def Compute_Cartesian_Speed(X, Y, dt):
    V = np.zeros(X.shape)
    Vx = np.diff(X) / dt
    Vy = np.diff(Y) / dt
    V[1:] = np.sqrt(Vx * Vx + Vy * Vy)
    return V


MovementTime = .5
NumIteration = 50
Time = np.linspace(0,MovementTime*1000,NumIteration)

fig,ax = plt.subplots(7,figsize = (6,28))
NUM_SIM = 100

def Compute_Cartesian_Speed(x):
    L1,L2 = 30,33
    ts,te,os,oe = x[0],x[1],x[2],x[3]
    Velx = -L1*np.sin(ts)*os - L2*np.sin(ts+te)*(os+oe)
    Vely = L1*np.cos(ts)*os + L2*np.cos(ts+te)*(os+oe)
    return np.sqrt(Velx**2 + Vely**2)
    
Cost_value = np.zeros((NUM_SIM,3))
Velocities = np.zeros((NUM_SIM,3,2,NumIteration))
Trajectories = np.zeros((NUM_SIM,3,2,NumIteration))
st = [0,50]
tg = [0,60]
ffpow = 4e-4

colors = ["#009E73","#0072B2","#E69F00"]
legend = ["ILQG","FL","DLQG"]
Cartesian_Vel = np.zeros((NUM_SIM,3,NumIteration))
for i in range(NUM_SIM):
    xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False,FF =  True,ff_power=ffpow)
    xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=1e-8,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True,FF = True,ff_power=ffpow)
    xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = WP,w2 = WP,w3 = WV,w4 = WV, Duration=MovementTime,r1 = WR,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True,FF = True,ff_power=ffpow)
    if i <= 10: 
        ax[0].plot(xILQG,yILQG, color=colors[0], linewidth=.6,linestyle = "--")
        ax[0].plot(xFL+15,yFL, color=colors[1], linewidth=.6,linestyle = "--")
        ax[0].plot(xLQG+30,yLQG, color=colors[2], linewidth=.6,linestyle = "--")
    Velocities[i,0] = zilqg[:,2:4].T
    Velocities[i,1] = xfl[:,2:4].T
    Velocities[i,2] = z[2:4]
    #print("ILQG end velocity is", zilqg[-1,3]," and for FL is ", xfl[-1,3], "\n")
    Trajectories[i,0] = xILQG,yILQG
    Trajectories[i,1] = xFL,yFL
    Trajectories[i,2] = xLQG,yLQG  
    Cartesian_Vel[i,0] = Compute_Cartesian_Speed(zilqg.T)
    Cartesian_Vel[i,1] = Compute_Cartesian_Speed(xfl.T)
    Cartesian_Vel[i,2] = Compute_Cartesian_Speed(z)
    Cost_value[i]=[Cost_function(zilqg,uILQG,tg = tg),Cost_function(xfl,uFL,tg = tg),Cost_function(z.T,uDLQG,tg = tg)]

    if i <= 10:
        xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False,FF =  False, ff_power=0)
        xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=1e-8,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True,FF = False,ff_power=0)
        xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = WP,w2 = WP,w3 = WV,w4 = WV, Duration=MovementTime,r1 = WR,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True,FF = False,ff_power=0)
    
        ax[0].plot(xILQG,yILQG, color="grey", linewidth=.6,linestyle = "-.")
        ax[0].plot(xFL+15,yFL, color="grey", linewidth=.6,linestyle = "-.")
        ax[0].plot(xLQG+30,yLQG, color="grey", linewidth=.6,linestyle = "-.")

for i in range(3):
    mean_vel = np.mean(Velocities[:,i,0],axis = 0)*180/pi
    std_vel = np.std(Velocities[:,i,0],axis = 0)*180/pi
    # Pot mean line
    ax[2].plot(Time, mean_vel, color=colors[i])
    # Pot standard deviation band
    ax[2].fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    mean_vel = np.mean(Velocities[:,i,1],axis = 0)*180/pi
    std_vel = np.std(Velocities[:,i,1],axis = 0)*180/pi
    # Pot mean line
    ax[2].plot(Time, mean_vel, color=colors[i],linestyle = "--")
    #ax[2,i].set_ylim(-4,3)
    # Pot standard deviation band
    ax[2].fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    delete_axis(ax[2],sides = ["top","right"])
    ax[2].set_xlabel("Movement Duration [ms]" , fontsize = 15)
    ax[2].set_xticks([0,100,200,300,400,500],labels = [0,100,200,300,400,500],fontsize = 14)
    ax[2].set_ylabel("Angular Velocity [deg/sec]" , fontsize = 15)
    ax[2].set_yticks([-180,0,180],labels = [-180,0,180],fontsize = 14)
    ax[1].set_yscale('log') 


box = ax[1].boxplot(Cost_value, patch_artist=True,
    medianprops=dict(color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),showfliers=False)

for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)



ax[0].set_aspect("equal")
ax[0].set_yticks([])
ax[0].set_xticks([])

delete_axis(ax[0])
for i in [1,3,4] : delete_axis(ax[i],sides =  ["top","right","bottom"])
    #ax[1,i].set_xticklabels([legend[i]],fontsize = 15)


ax[1].set_xticks([])
ax[1].set_ylim(.001,1)
ax[1].set_yticks([.001,.01,.01,.1,1])
ax[1].tick_params(axis='y', labelsize=14)
ax[1].set_ylabel("Movement Cost",fontsize = 15)

ax[3].set_xticks([])
ax[3].tick_params(axis='y', labelsize=14)
ax[3].set_ylabel("Terminal Endpoint Error [cm]",fontsize = 15)

ax[4].set_xticks([])
ax[4].tick_params(axis='y', labelsize=14)
ax[4].set_ylabel("Terminal Endpoint Velocity [cm/sec]",fontsize = 15)

ax[5].set_xticks([])
ax[5].tick_params(axis='y', labelsize=14)

ax[6].set_xticks([])
ax[6].tick_params(axis='y', labelsize=14)

for i in range(3): 
    ax[0].plot([0+15*i],[tg[1]],marker = "s",markersize = 8,markeredgecolor = "grey",markerfacecolor='grey',zorder = 0,markeredgewidth = 3)

TerminalEndPointVel = np.copy(Cartesian_Vel[:,:, -1])
TerminalEndPoint = np.sqrt((Trajectories[:,:,0,-1])**2+(Trajectories[:,:,1,-1]-60)**2)
TerminalAngVel = np.abs(Velocities[:,:,:,-1])

box2 = ax[3].boxplot(TerminalEndPoint, patch_artist=True,
    medianprops=dict(color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),showfliers=False)

box3 = ax[4].boxplot(TerminalEndPointVel, patch_artist=True,
    medianprops=dict(color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),showfliers=False)

box4 = ax[5].boxplot(TerminalAngVel[:,:,0]*180/np.pi, patch_artist=True,
    medianprops=dict(color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),showfliers=False)

box5 = ax[6].boxplot(TerminalAngVel[:,:,1]*180/np.pi, patch_artist=True,
    medianprops=dict(color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),showfliers=False)

for box in [box2,box3,box4,box5]:
    for patch, color in zip(box['boxes'], colors):
        patch.set_facecolor(color)
plt.savefig("PerturbedMax.svg",dpi = 300)
plt.show()
# Out:
# d:\thyriona\Desktop\Codes\My_research\PhD\Controllers\ILQG.py:457: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[k] = Q[k] + A[k].T @ S[k + 1] @ A[k] - G.T @ Hinv @ G
# d:\thyriona\Desktop\Codes\My_research\PhD\Controllers\ILQG.py:458: ComplexWarning: Casting complex values to real discards the imaginary part
#   sbold[k] = qbold[k] + A[k].T @ sbold[k + 1] - G.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\PhD\Controllers\ILQG.py:459: ComplexWarning: Casting complex values to real discards the imaginary part
#   s[k] = q[k] + s[k + 1] + 0.5 * temp3 - 0.5 * gbold.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\PhD\Controllers\ILQG.py:461: ComplexWarning: Casting complex values to real discards the imaginary part
#   l[k] = -Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\PhD\Controllers\ILQG.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   L[k] = -Hinv @ G

# %%
from Controllers.FL import *
from Controllers.ILQG import *
from Controllers.LQGControllers import *
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib import gridspec


MN = 5e-4

WP = 20000
WV =  1
WR = .5


DURATIONS = [.3,.4,.5,.6,.7,.8,.9,1]
DURATIONS_ms = [300,400,500,600,700,800,900,1000]
colors = ["#009E73","#0072B2","#E69F00"]
legend = ["ILQG","FL","DLQG"]

def Cost_function(x,u,w1 = WP,w2 = WV,r = WR,tg = [0,0] ):
    target1,target2 = compute_angles_from_cartesian(tg[0],tg[1])
    thetas,thetae,omegas,omegae = x[-1,:4]
    
    return w1*(thetas-target1)**2 + w1*(thetae-target2)**2 + w2*(omegas**2+omegae**2)+ np.sum(u*u) * r




MovementTime = .6
NumIteration = 60
Time = np.linspace(0,MovementTime*1000,NumIteration+1)

fig,ax = plt.subplots(12,figsize = (5,40))

NUM_SIM = 100

def Compute_Cartesian_Speed(x):
    L1,L2 = 30,33
    ts,te,os,oe = x[0],x[1],x[2],x[3]
    Velx = -L1*np.sin(ts)*os - L2*np.sin(ts+te)*(os+oe)
    Vely = L1*np.cos(ts)*os + L2*np.cos(ts+te)*(os+oe)
    return Velx,Vely,np.sqrt(Velx**2 + Vely**2)
    
Cost_value = np.zeros((NUM_SIM,3))
Cost_value_NOFF = np.zeros((NUM_SIM,3))
Pos_Error = np.zeros((NUM_SIM,3,2))
Velocities = np.zeros((NUM_SIM,3,2,NumIteration+1))
VelocitiesNOFF = np.zeros((NUM_SIM,3,2,NumIteration+1))
Trajectories = np.zeros((NUM_SIM,3,2,NumIteration+1))
st = [0,45]
tg = [0,60]
ffpow = 4e-4

colors = ["#009E73","#0072B2","#E69F00"]
legend = ["ILQG","FL","DLQG"]
absolute_cartesian_velocity = np.zeros((NUM_SIM,3,NumIteration+1))
xy_cartesian_velocity = np.zeros((NUM_SIM,3,2,NumIteration+1))
for i in range(NUM_SIM):
    xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False,FF =  True,ff_power=ffpow,motornoise_variance=MN)
    xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=1e-8,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True,FF = True,ff_power=ffpow,motornoise_variance=MN)
    xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = WP,w2 = WP,w3 = WV,w4 = WV, Duration=MovementTime,r1 = WR,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True,FF = True,ff_power=ffpow,motornoise_variance=MN)
    if i <= 10: 
        ax[0].plot(xILQG,yILQG, color=colors[0], linewidth=.6,linestyle = "--")
        ax[0].plot(xFL+15,yFL, color=colors[1], linewidth=.6,linestyle = "--")
        ax[0].plot(xLQG+30,yLQG, color=colors[2], linewidth=.6,linestyle = "--")
    Velocities[i,0] = zilqg[:,2:4].T
    Velocities[i,1] = xfl[:,2:4].T
    Velocities[i,2] = z[2:4]
    tg_angles = np.array(compute_angles_from_cartesian(tg[0],tg[1]))
    Pos_Error[i,0] = np.abs(zilqg[-1,:2] - tg_angles)
    Pos_Error[i,1] = np.abs(xfl[-1,:2] - tg_angles)
    Pos_Error[i,2] = np.abs(z[:2,-1] - tg_angles)
    #print("ILQG end velocity is", zilqg[-1,3]," and for FL is ", xfl[-1,3], "\n")
    Trajectories[i,0] = xILQG,yILQG
    Trajectories[i,1] = xFL,yFL
    Trajectories[i,2] = xLQG,yLQG  
    xy_cartesian_velocity[i,0,0],xy_cartesian_velocity[i,0,1],absolute_cartesian_velocity[i,0] = Compute_Cartesian_Speed(zilqg.T)
    xy_cartesian_velocity[i,1,0],xy_cartesian_velocity[i,1,1],absolute_cartesian_velocity[i,1] = Compute_Cartesian_Speed(xfl.T)
    xy_cartesian_velocity[i,2,0],xy_cartesian_velocity[i,2,1],absolute_cartesian_velocity[i,2] = Compute_Cartesian_Speed(z)
    Cost_value[i]=[Cost_function(zilqg,uILQG,tg = tg),Cost_function(xfl,uFL,tg = tg),Cost_function(z.T,uDLQG,tg = tg)]

    xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False,FF =  False, ff_power=0,motornoise_variance=MN)
    xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=1e-8,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True,FF = False,ff_power=0,motornoise_variance=MN)
    xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = WP,w2 = WP,w3 = WV,w4 = WV, Duration=MovementTime,r1 = WR,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True,FF = False,ff_power=0,motornoise_variance=MN)
    Cost_value_NOFF[i]=[Cost_function(zilqg,uILQG,tg = tg),Cost_function(xfl,uFL,tg = tg),Cost_function(z.T,uDLQG,tg = tg)]

    VelocitiesNOFF[i,0] = zilqg[:,2:4].T
    VelocitiesNOFF[i,1] = xfl[:,2:4].T
    VelocitiesNOFF[i,2] = z[2:4]
    
    if i <= 10:
        
        ax[0].plot(xILQG,yILQG, color="grey", linewidth=.6,linestyle = "-.")
        ax[0].plot(xFL+15,yFL, color="grey", linewidth=.6,linestyle = "-.")
        ax[0].plot(xLQG+30,yLQG, color="grey", linewidth=.6,linestyle = "-.")

for idxvel, vel in enumerate([Velocities,VelocitiesNOFF]): 
    axtoplot = ax[idxvel*9+2]
    for i in range(3):
        mean_vel = np.mean(vel[:,i,0],axis = 0)*180/pi
        std_vel = np.std(vel[:,i,0],axis = 0)*180/pi
        # Pot mean line
        axtoplot.plot(Time, mean_vel, color=colors[i])
        # Pot standard deviation band
        axtoplot.fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
        mean_vel = np.mean(vel[:,i,1],axis = 0)*180/pi
        std_vel = np.std(vel[:,i,1],axis = 0)*180/pi
        # Pot mean line
        axtoplot.plot(Time, mean_vel, color=colors[i],linestyle = "--")
        #ax[2,i].set_ylim(-4,3)
        # Pot standard deviation band
        axtoplot.fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
        delete_axis(axtoplot,sides = ["top","right"])
        axtoplot.set_xlabel("Movement Duration [ms]" , fontsize = 15)
        axtoplot.set_xticks([0,100,200,300,400,500],labels = [0,100,200,300,400,500],fontsize = 14)
        axtoplot.set_ylabel("Angular Velocity [deg/sec]" , fontsize = 15)
        axtoplot.set_yticks([-180,0,180],labels = [-180,0,180],fontsize = 14)

        
for i in range(3):
    mean_vel = np.mean(absolute_cartesian_velocity[:,i],axis = 0)
    std_vel = np.std(absolute_cartesian_velocity[:,i],axis = 0)
    # Pot mean line
    ax[7].plot(Time, mean_vel, color=colors[i])
    # Pot standard deviation band
    ax[7].fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    #ax[2,i].set_ylim(-4,3)
    # Pot standard deviation band
    ax[7].fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    delete_axis(ax[7],sides = ["top","right"])
    ax[7].set_xlabel("Movement Duration [ms]" , fontsize = 15)
    ax[7].set_xticks([0,100,200,300,400,500,600],labels = [0,100,200,300,400,500,600],fontsize = 14)
    ax[7].set_ylabel("Velocity [cm/sec]" , fontsize = 15)
    ax[7].set_yticks([-20,0,20],labels = [-20,0,20],fontsize = 14)
    mean_vel = np.mean(xy_cartesian_velocity[:,i,0],axis = 0)
    std_vel = np.std(xy_cartesian_velocity[:,i,0],axis = 0)
    # Pot mean line
    ax[8].plot(Time, mean_vel, color=colors[i])
    # Pot standard deviation band
    ax[8].fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    #ax[2,i].set_ylim(-4,3)
    # Pot standard deviation band
    ax[8].fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    delete_axis(ax[8],sides = ["top","right"])
    ax[8].set_xlabel("Movement Duration [ms]" , fontsize = 15)
    ax[8].set_xticks([0,100,200,300,400,500,600],labels = [0,100,200,300,400,500,600],fontsize = 14)
    ax[8].set_ylabel("Velocity [cm/sec]" , fontsize = 15)
    ax[8].set_yticks([-20,0,20],labels = [-20,0,20],fontsize = 14)
    mean_vel = np.mean(xy_cartesian_velocity[:,i,1],axis = 0)
    std_vel = np.std(xy_cartesian_velocity[:,i,1],axis = 0)
    # Pot mean line
    ax[9].plot(Time, mean_vel, color=colors[i])
    # Pot standard deviation band
    ax[9].fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    #ax[2,i].set_ylim(-4,3)
    # Pot standard deviation band
    ax[9].fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    delete_axis(ax[9],sides = ["top","right"])
    ax[9].set_xlabel("Movement Duration [ms]" , fontsize = 15)
    ax[9].set_xticks([0,100,200,300,400,500,600],labels = [0,100,200,300,400,500,600],fontsize = 14)
    ax[9].set_ylabel("Velocity [cm/sec]" , fontsize = 15)
    ax[9].set_yticks([-20,0,20],labels = [-20,0,20],fontsize = 14)



for i in range(2):
    box = ax[1].boxplot(Pos_Error[:,:,i]*180/np.pi,positions = [i*3+1,i*3+2,i*3+3], patch_artist=True,
        medianprops=dict(color='black'),
        whiskerprops=dict(color='black'),
        capprops=dict(color='black'),showfliers=False)

    for patch, color in zip(box['boxes'], colors):
        patch.set_facecolor(color)



ax[0].set_aspect("equal")
ax[0].set_yticks([])
ax[0].set_xticks([])

delete_axis(ax[0])
for i in [1,3,4] : delete_axis(ax[i],sides =  ["top","right","bottom"])
    #ax[1,i].set_xticklabels([legend[i]],fontsize = 15)


ax[1].set_xticks([])
ax[1].tick_params(axis='y', labelsize=14)
ax[1].set_ylabel("Movement Cost",fontsize = 15)

ax[3].set_xticks([])
ax[3].tick_params(axis='y', labelsize=14)
ax[3].set_ylabel("Terminal Endpoint Error [cm]",fontsize = 15)

ax[4].set_xticks([])
ax[4].tick_params(axis='y', labelsize=14)
ax[4].set_ylabel("Terminal Endpoint Velocity [cm/sec]",fontsize = 15)

ax[5].set_xticks([])
ax[5].tick_params(axis='y', labelsize=14)

ax[6].set_xticks([])
ax[6].tick_params(axis='y', labelsize=14)

for i in range(3): 
    ax[0].plot([0+15*i],[tg[1]],marker = "s",markersize = 8,markeredgecolor = "grey",markerfacecolor='grey',zorder = 0,markeredgewidth = 3)

TerminalEndPointVel = np.copy(absolute_cartesian_velocity[:,:, -1])
TerminalEndPoint = np.sqrt((Trajectories[:,:,0,-1])**2+(Trajectories[:,:,1,-1]-60)**2)
TerminalAngVel = np.abs(Velocities[:,:,:,-1])

box2 = ax[3].boxplot(TerminalEndPoint, patch_artist=True,
    medianprops=dict(color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),showfliers=False)

box3 = ax[4].boxplot(TerminalEndPointVel, patch_artist=True,
    medianprops=dict(color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),showfliers=False)

box4 = ax[5].boxplot(TerminalAngVel[:,:,0]*180/np.pi, patch_artist=True,
    medianprops=dict(color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),showfliers=False)

box5 = ax[6].boxplot(TerminalAngVel[:,:,1]*180/np.pi, patch_artist=True,
    medianprops=dict(color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),showfliers=False)

for box in [box2,box3,box4,box5]:
    for patch, color in zip(box['boxes'], colors):
        patch.set_facecolor(color)
plt.savefig("FF3Controllers.svg",dpi = 300)
plt.show()

from matplotlib.patches import Ellipse
from scipy.stats import chi2

def confidence_ellipse(x, y, ax, p=95, color="black"):
    cov = np.cov(x, y)
    mean = [np.mean(x), np.mean(y)]

    # valeurs propres
    vals, vecs = np.linalg.eigh(cov)
    order = vals.argsort()[::-1]
    vals, vecs = vals[order], vecs[:, order]

    # angle de l’ellipse
    theta = np.degrees(np.arctan2(*vecs[:,0][::-1]))

    # rayon selon chi²
    r2 = chi2.ppf(p/100, 2)
    width, height = 2 * np.sqrt(vals * r2)

    ellipse = Ellipse(
        xy=mean,
        width=width,
        height=height,
        angle=theta,
        color=color,
        alpha=0.3
    )
    ax.add_patch(ellipse)
    ax.plot(mean[0], mean[1], marker='o', color=color, markersize=5)
    ax.plot(np.linspace(0,.5,100), np.linspace(0,.5,100), color='grey', linestyle='--')

def percentile_cross(x, y, ax, p=95, color="black"):
    """
    Plot a percentile cross centered at the mean of x and y.
    """
    x = np.asarray(x)
    y = np.asarray(y)

    # Mean
    mx = np.mean(x)
    my = np.mean(y)

    # Percentile bounds
    alpha = (100 - p) / 2
    x_low, x_high = np.percentile(x, [alpha, 100 - alpha])
    y_low, y_high = np.percentile(y, [alpha, 100 - alpha])

    print(x_low, x_high, y_low, y_high)

    # Horizontal line (X uncertainty)
    ax.plot([x_low, x_high], [my, my], color=color, linewidth=1.5)

    # Vertical line (Y uncertainty)
    ax.plot([mx, mx], [y_low, y_high],color=color,linewidth = 1.5)

    # Mean marker
    ax.scatter(mx, my, marker='o', color=color, s = 30)

fig,ax = plt.subplots(figsize = (5,5))
Mean_Cost = np.mean(Cost_value,axis = 0)
Mean_Cost_NOFF = np.mean(Cost_value_NOFF,axis = 0)
for i in range(3):
    percentile_cross(Cost_value_NOFF[:,i], Cost_value[:,i], ax, color=colors[i])
#ax.set_xlim(-.05,0.6)
#ax.set_ylim(-.05,0.6)
ax.set_xlabel("Cost without FF",fontsize = 14)
ax.set_ylabel("Cost with FF",fontsize = 14)

plt.savefig("FFFV.svg",dpi = 300)

plt.show()
# Out:
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:469: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[k] = Q[k] + A[k].T @ S[k + 1] @ A[k] - G.T @ Hinv @ G
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:470: ComplexWarning: Casting complex values to real discards the imaginary part
#   sbold[k] = qbold[k] + A[k].T @ sbold[k + 1] - G.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:471: ComplexWarning: Casting complex values to real discards the imaginary part
#   s[k] = q[k] + s[k + 1] + 0.5 * temp3 - 0.5 * gbold.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:473: ComplexWarning: Casting complex values to real discards the imaginary part
#   l[k] = -Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:474: ComplexWarning: Casting complex values to real discards the imaginary part
#   L[k] = -Hinv @ G

# %%
import os
os.chdir('..')

from Controllers.FL import *
from Controllers.ILQG import *
from Controllers.LQGControllers import *
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib import gridspec

MN = 1e-3
WP = 100
WV = .05
WR = .1

def Cost_function(x,u,w1 = WP,w2 = WV,r = WR,tg = [0,0] ):
    target1,target2 = compute_angles_from_cartesian(tg[0],tg[1])
    thetas,thetae,omegas,omegae = x[-1,:4]
    
    return w1*(thetas-target1)**2 + w1*(thetae-target2)**2 + w2*(omegas**2+omegae**2)+ np.sum(u*u) * r



def sensitivity_analysis(wp,wv,wr,wrfl,num_sim):

    MovementTime = .6
    NumIteration = 60
    Cost_value = np.zeros((num_sim,3))

    st = [0,45]
    tg = [0,60]
    ffpow = 4e-4

    for i in range(num_sim):
        xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,wp,wv,wr,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False,FF =  True,ff_power=ffpow)
        xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=wp,w2=wp,w3=wv,w4=wv,r=wrfl,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True,FF = True,ff_power=ffpow)
        xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = wp,w2 = wp,w3 = wv,w4 = wv, Duration=MovementTime,r1 = wr,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True,FF = True,ff_power=ffpow)
        
        Cost_value[i]=[Cost_function(zilqg,uILQG,wp,wv,wr,tg = tg),Cost_function(xfl,uFL,wp,wv,wr,tg = tg),Cost_function(z.T,uDLQG,wp,wv,wr,tg = tg)]

        #xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False,FF =  False, ff_power=0)
        #xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=1e-8,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True,FF = False,ff_power=0)
        #xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = WP,w2 = WP,w3 = WV,w4 = WV, Duration=MovementTime,r1 = WR,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True,FF = False,ff_power=0)
        #Cost_value_NOFF[i]=[Cost_function(zilqg,uILQG,tg = tg),Cost_function(xfl,uFL,tg = tg),Cost_function(z.T,uDLQG,tg = tg)]
    
    return Cost_value

fig,ax = plt.subplots(3,figsize = (8,8)) 
colors = ["#009E73","#0072B2","#E69F00"]
legend = ["ILQG","FL","DLQG"]       
delete_axis(ax[1],sides =  ["top","right"])

NUM_SIM = 100
NUM_DISCRETIZATION = 20
wp_values = np.linspace(10,1000,NUM_DISCRETIZATION)
wv_values = np.linspace(0.005,.5,NUM_DISCRETIZATION)
wr_values = np.linspace(0.02,2,NUM_DISCRETIZATION)

Average_Cost = np.zeros((NUM_DISCRETIZATION,3))
for i in range(NUM_DISCRETIZATION):
    Cost_value = sensitivity_analysis(wp_values[i],WV,WR,1e-8,NUM_SIM)
    Average_Cost[i] = np.mean(Cost_value,axis = 0)
    print("Done with iteration ",i)

ax[0].plot(wp_values,Average_Cost[:,0],color = colors[0],label = legend[0])
ax[0].plot(wp_values,Average_Cost[:,1],color = colors[1],label = legend[1])
ax[0].plot(wp_values,Average_Cost[:,2],color = colors[2],label = legend[2])
ax[0].set_yscale("log")

Average_Cost = np.zeros((NUM_DISCRETIZATION,3))
for i in range(NUM_DISCRETIZATION):
    Cost_value = sensitivity_analysis(WP,wv_values[i],WR,1e-8,NUM_SIM)
    Average_Cost[i] = np.mean(Cost_value,axis = 0)
    print("Done with iteration ",i)

ax[1].plot(wv_values,Average_Cost[:,0],color = colors[0],label = legend[0])
ax[1].plot(wv_values,Average_Cost[:,1],color = colors[1],label = legend[1])
ax[1].plot(wv_values,Average_Cost[:,2],color = colors[2],label = legend[2])
ax[1].set_yscale("log")

Average_Cost = np.zeros((NUM_DISCRETIZATION,3))
for i in range(NUM_DISCRETIZATION):
    Cost_value = sensitivity_analysis(WP,WV,wr_values[i],1e-8,NUM_SIM)
    Average_Cost[i] = np.mean(Cost_value,axis = 0)
    print("Done with iteration ",i)

ax[2].plot(wr_values,Average_Cost[:,0],color = colors[0],label = legend[0])
ax[2].plot(wr_values,Average_Cost[:,1],color = colors[1],label = legend[1])
ax[2].plot(wr_values,Average_Cost[:,2],color = colors[2],label = legend[2])
ax[2].set_yscale("log")

plt.savefig("Sensitivity_Analysis.svg",dpi = 300)
# Out:
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:469: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[k] = Q[k] + A[k].T @ S[k + 1] @ A[k] - G.T @ Hinv @ G
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:470: ComplexWarning: Casting complex values to real discards the imaginary part
#   sbold[k] = qbold[k] + A[k].T @ sbold[k + 1] - G.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:471: ComplexWarning: Casting complex values to real discards the imaginary part
#   s[k] = q[k] + s[k + 1] + 0.5 * temp3 - 0.5 * gbold.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:473: ComplexWarning: Casting complex values to real discards the imaginary part
#   l[k] = -Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:474: ComplexWarning: Casting complex values to real discards the imaginary part
#   L[k] = -Hinv @ G
# Done with iteration  0
# ...

# %%
st,tg = longmovement_1()
st,tg = np.array(st),np.array(tg)
temp = st[1]
st[1] = tg[1]
tg[1] = temp

print(st,tg)
print(np.sqrt((st[0]-tg[0])**2+(st[1]-tg[1])**2))

print(46.155/55*20)
# Out:
# [-22.61382074  45.51663773] [30.45417667 31.06691813]
# 55.00006132223064
# 16.783636363636365

# %%
st,tg = longmovement_2()

MovementTime = .6
NumIteration = 60
Time = np.linspace(0,MovementTime*1000,NumIteration)

fig= plt.figure(figsize = (22,40))
gs = gridspec.GridSpec(3, 6)
ax1 = fig.add_subplot(gs[0, 0:2]) 
ax2 = fig.add_subplot(gs[0, 2:4])  
ax3 = fig.add_subplot(gs[0, 4:6])  


ax41 = fig.add_subplot(gs[1, 0:2])
ax42 = fig.add_subplot(gs[1, 2:4])
ax43 = fig.add_subplot(gs[1, 4:6])

ax40 = np.array([ax41,ax42,ax43])
ax6 = fig.add_subplot(gs[2, :3])
ax7= fig.add_subplot(gs[2, 3:])
NUM_SIM = 100
MV = 1e-3
Cost_value = np.zeros((NUM_SIM,3))
Velocities = np.zeros((NUM_SIM,3,2,NumIteration))
colors = ["#30F077","#66E4FF","#FFD363"]
legend = ["ILQG","FL","DLQG"]
WP = 100
WV = .05
WR = .1
def Cost_function(x,u,tg = [0,0] ):
    target1,target2 = compute_angles_from_cartesian(tg[0],tg[1])
    thetas,thetae,omegas,omegae = x[-1,:4]
    return WP*(thetas-target1)**2 + WP*(thetae-target2)**2 + WV*(omegas**2+omegae**2)+ np.sum(u*u) *WR * MovementTime/NumIteration


for i in range(NUM_SIM):
    xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False,FF =  False,motornoise_variance=MV)
    xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=1e-7,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True,FF = False,motornoise_variance=MV)
    xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = WP,w2 = WP,w3 = WV,w4 = WV, Duration=MovementTime,r1 = WR,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True,FF = False,motornoise_variance=MV)
    if i <= 10: 
        ax1.plot(xILQG,yILQG, color=colors[0], linewidth=.5)
        ax2.plot(xFL,yFL, color=colors[1], linewidth=.5)
        ax3.plot(xLQG,yLQG, color=colors[2], linewidth=.5)
    Velocities[i,0] = zilqg[:,2:4].T
    Velocities[i,1] = xfl[:,2:4].T
    Velocities[i,2] = z.T[:,2:4].T
        
    Cost_value[i]=[Cost_function(zilqg,uILQG,tg = tg),Cost_function(xfl,uFL,tg = tg),Cost_function(z.T,uDLQG,tg = tg)]

ax41.set_ylabel("Angular Velocity [deg/sec]" , fontsize = 22)

for i in range(3):
    ax4 = ax40[i]
    ax4.plot(Time,np.zeros(len(Time)),color = "black")
    mean_vel = np.mean(Velocities[:,i,0],axis = 0)*180/pi
    std_vel = np.std(Velocities[:,i,0],axis = 0)*180/pi
    ax4.plot(Time, mean_vel, color=colors[i])
    ax4.fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    mean_vel = np.mean(Velocities[:,i,1],axis = 0)*180/pi
    std_vel = np.std(Velocities[:,i,1],axis = 0)*180/pi
    ax4.plot(Time, mean_vel, color=colors[i], linestyle = "--")
    ax4.fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    delete_axis(ax4,sides = ["top","right"])
    ax4.set_xlabel("Time [ms]" , fontsize = 22)
    ax4.set_xticks([0,600],labels = [0,600],fontsize = 20)
    ax4.set_ylim(-270,320)
    
    ax4.set_yticks([-270,-180,-90,0,90,180,270],labels = ["","","","","","",""],fontsize = 20)
    ax6.set_yscale('log') 
box = ax6.boxplot(Cost_value, patch_artist=True,
    medianprops=dict(color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),showfliers=False)

for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)


for ax in [ax1,ax2,ax3]:
    ax.set_aspect("equal")
    ax.set_yticks([])
    ax.set_xticks([])
    delete_axis(ax)
    circle = plt.Circle((tg[0],tg[1]), 1.5, edgecolor='grey',facecolor = "grey", linewidth=3)
    ax.add_patch(circle)
    square = plt.Rectangle((st[0]-1.5,st[1]-1.5), 3,3, edgecolor='grey',facecolor = "grey", linewidth=3)
    ax.add_patch(square)
ax6.set_xticks([])

delete_axis(ax6)


ax6.tick_params(axis='y', labelsize=20)
ax6.set_ylabel("Movement Cost",fontsize = 22)
colors = ["#30BE77","#40C2DE","#F0AA00"]
st,tg = longmovement_1()
Cost_value = np.zeros((NUM_SIM,3))
Velocities = np.zeros((NUM_SIM,3,2,NumIteration))

for i in range(NUM_SIM):
    xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False,FF =  False,motornoise_variance=MV)
    xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=1e-8,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True,FF = False,motornoise_variance=MV)
    xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = WP,w2 = WP,w3 = WV,w4 = WV, Duration=MovementTime,r1 = WR,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True,FF = False,motornoise_variance=MV)
    if i <= 10: 
        ax1.plot(xILQG,yILQG, color=colors[0], linewidth=.5)
        ax2.plot(xFL,yFL, color=colors[1], linewidth=.5)
        ax3.plot(xLQG,yLQG, color=colors[2], linewidth=.5)
    Velocities[i,0] = zilqg[:,2:4].T
    Velocities[i,1] = xfl[:,2:4].T
    Velocities[i,2] = z.T[:,2:4].T
        
    Cost_value[i]=[Cost_function(zilqg,uILQG,tg = tg),Cost_function(xfl,uFL,tg = tg),Cost_function(z.T,uDLQG,tg = tg)]

for i in range(3):
    ax5 = ax40[i]
    ax5.plot(Time,np.zeros(len(Time)),color = "black")
    mean_vel = np.mean(Velocities[:,i,0],axis = 0)*180/pi
    std_vel = np.std(Velocities[:,i,0],axis = 0)*180/pi
    ax5.plot(Time, mean_vel, color=colors[i])
    ax5.fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    mean_vel = np.mean(Velocities[:,i,1],axis = 0)*180/pi
    std_vel = np.std(Velocities[:,i,1],axis = 0)*180/pi
    ax5.plot(Time, mean_vel, color=colors[i], linestyle = "--")
    ax5.fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    delete_axis(ax5,sides = ["top","right"])
    ax5.set_yticks([-270,-180,-90,0,90,180,270],labels = ["","","","","","",""],fontsize = 20)
    ax5.set_xlabel("Time [ms]" , fontsize = 22)
    ax5.set_xticks([0,600],labels = [0,600],fontsize = 20)
    ax5.set_ylim(-270,320)
    

    ax7.set_yscale('log') 

ax41.set_yticks([-270,-180,-90,0,90,180,270],labels = [-270,-180,-90,0,90,180,270],fontsize = 20)

box = ax7.boxplot(Cost_value, patch_artist=True,
    medianprops=dict(color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),showfliers=False)

for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)


for ax in [ax1,ax2,ax3]:
    circle = plt.Circle((tg[0],tg[1]), 1.5, edgecolor='grey',facecolor = "grey", linewidth=3)
    ax.add_patch(circle)
    square = plt.Rectangle((st[0]-1.5,st[1]-1.5), 3,3, edgecolor='grey',facecolor = "grey", linewidth=3)
    ax.add_patch(square)
    
ax7.set_xticks([])

delete_axis(ax7)


ax7.tick_params(axis='y', labelsize=20)
ax7.set_ylabel("Movement Cost",fontsize = 22)
ax41.grid(axis="y")
ax42.grid(axis="y")
ax43.grid(axis="y")

plt.savefig("LongMove2.svg",dpi = 500)
plt.show()
# Out:
# d:\thyriona\Desktop\Codes\FL\PhD\Controllers\ILQG.py:451: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[k] = Q[k] + A[k].T @ S[k + 1] @ A[k] - G.T @ Hinv @ G
# d:\thyriona\Desktop\Codes\FL\PhD\Controllers\ILQG.py:452: ComplexWarning: Casting complex values to real discards the imaginary part
#   sbold[k] = qbold[k] + A[k].T @ sbold[k + 1] - G.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\FL\PhD\Controllers\ILQG.py:453: ComplexWarning: Casting complex values to real discards the imaginary part
#   s[k] = q[k] + s[k + 1] + 0.5 * temp3 - 0.5 * gbold.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\FL\PhD\Controllers\ILQG.py:455: ComplexWarning: Casting complex values to real discards the imaginary part
#   l[k] = -Hinv @ gbold
# d:\thyriona\Desktop\Codes\FL\PhD\Controllers\ILQG.py:456: ComplexWarning: Casting complex values to real discards the imaginary part
#   L[k] = -Hinv @ G
# ...

# %%
st,tg = longmovement_1()
st,tg = np.array(st),np.array(tg)
temp = st[1]
st[1] = tg[1]
tg[1] = temp
tg[1] -= 10

MovementTime = .6
NumIteration = 60
Time = np.linspace(0,MovementTime*1000,NumIteration)

fig, [ax1,ax2]= plt.subplots(2,1,figsize = (4,20))
NUM_SIM = 100
MV = 1e-3
Cost_value = np.zeros((NUM_SIM,3))
Velocities = np.zeros((NUM_SIM,3,2,NumIteration))
colors = ["#30F077","#66E4FF","#FFD363"]
legend = ["ILQG","FL","DLQG"]
WP = 100
WV = .05
WR = .1
def Cost_function(x,u,tg = [0,0] ):
    target1,target2 = compute_angles_from_cartesian(tg[0],tg[1])
    thetas,thetae,omegas,omegae = x[-1,:4]
    return WP*(thetas-target1)**2 + WP*(thetae-target2)**2 + WV*(omegas**2+omegae**2)+ np.sum(u*u) *WR * MovementTime/NumIteration


for i in range(NUM_SIM):
    xILQG,yILQG,zilqg,uILQG=ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False,FF =  False,motornoise_variance=MV)
    Velocities[i,0] = zilqg[:,2:4].T
        

for i in range(1):
    mean_vel = np.mean(Velocities[:,i,0],axis = 0)*180/pi
    std_vel = np.std(Velocities[:,i,0],axis = 0)*180/pi
    ax1.plot(Time, mean_vel, color=colors[i])
    ax1.fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    mean_vel = np.mean(Velocities[:,i,1],axis = 0)*180/pi
    std_vel = np.std(Velocities[:,i,1],axis = 0)*180/pi
    ax1.plot(Time, mean_vel, color=colors[i])
    ax1.fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    delete_axis(ax1,sides = ["top","right"])
    ax1.set_xlabel("Movement Duration [ms]" , fontsize = 16)
    ax1.set_xticks([0,100,200,300,400,500,600],labels = [0,100,200,300,400,500,600],fontsize = 15)
    ax1.set_ylabel("Angular Velocity [deg/sec]" , fontsize = 16)
    ax1.set_yticks([-360,-270,-180,-90,0,90,180,270,360],labels = [-360,-270,-180,-90,0,90,180,270,360],fontsize = 15)



colors = ["#30BE77","#40C2DE","#F0AA00"]
st,tg = longmovement_1()
st,tg = np.array(st),np.array(tg)
st[1] -= 10
Cost_value = np.zeros((NUM_SIM,3))
Velocities = np.zeros((NUM_SIM,3,2,NumIteration))

for i in range(NUM_SIM):
    xILQG,yILQG,zilqg,uILQG=ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False,FF =  False,motornoise_variance=MV)
    Velocities[i,0] = zilqg[:,2:4].T
        

for i in range(1):
    mean_vel = np.mean(Velocities[:,i,0],axis = 0)*180/pi
    std_vel = np.std(Velocities[:,i,0],axis = 0)*180/pi
    ax2.plot(Time, mean_vel, color=colors[i])
    ax2.fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    mean_vel = np.mean(Velocities[:,i,1],axis = 0)*180/pi
    std_vel = np.std(Velocities[:,i,1],axis = 0)*180/pi
    ax2.plot(Time, mean_vel, color=colors[i])
    ax2.fill_between(Time, mean_vel - std_vel, mean_vel + std_vel, color=colors[i], alpha=0.3)
    delete_axis(ax2,sides = ["top","right"])
    ax2.set_xlabel("Movement Duration [ms]" , fontsize = 16)
    ax2.set_xticks([0,100,200,300,400,500,600],labels = [0,100,200,300,400,500,600],fontsize = 15)
    ax2.set_yticks([-360,-270,-180,-90,0,90,180,270,360],labels = [-360,-270,-180,-90,0,90,180,270,360],fontsize = 15)



ax1.grid(axis="y")
ax2.grid(axis="y")
plt.savefig("ILQGVEL.png",dpi = 500)
plt.show()
# Out:
# c:\Users\talex\Desktop\PhD\FL\Controllers\ILQG6Muscles.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[k] = Q[k] + A[k].T @ S[k + 1] @ A[k] - G.T @ Hinv @ G
# c:\Users\talex\Desktop\PhD\FL\Controllers\ILQG6Muscles.py:539: ComplexWarning: Casting complex values to real discards the imaginary part
#   sbold[k] = qbold[k] + A[k].T @ sbold[k + 1] - G.T @ Hinv @ gbold
# c:\Users\talex\Desktop\PhD\FL\Controllers\ILQG6Muscles.py:540: ComplexWarning: Casting complex values to real discards the imaginary part
#   s[k] = q[k] + s[k + 1] + 0.5 * temp3 - 0.5 * gbold.T @ Hinv @ gbold
# c:\Users\talex\Desktop\PhD\FL\Controllers\ILQG6Muscles.py:542: ComplexWarning: Casting complex values to real discards the imaginary part
#   l[k] = -Hinv @ gbold
# c:\Users\talex\Desktop\PhD\FL\Controllers\ILQG6Muscles.py:543: ComplexWarning: Casting complex values to real discards the imaginary part
#   L[k] = -Hinv @ G
# ...

# %%
WC = .01
TAU = .03
PERCENT = .7
def ToCartesian(s,e):
    X = np.cos(s + e) * 33 + np.cos(s) * 30
    Y = np.sin(s + e) * 33 + np.sin(s) * 30

    return X, Y
def compute_percent(x0,xf):
    x0,xf = np.array(x0),np.array(xf)
    ts,te= compute_angles_from_cartesian(xf[0],xf[1])
    ts0,te0 = compute_angles_from_cartesian(x0[0],x0[1])
    te_incr,ts_incr = (te0 + .001*(te-te0)),(ts0 + .001*(ts-ts0))
    x_incr,y_incr = ToCartesian(ts_incr,te_incr)
    angle_objective = np.arctan2(xf[1]-x0[1],xf[0]-x0[0])*180/pi
    actual_angle = np.arctan2(y_incr-x0[1],x_incr-x0[0])*180/pi
    print(abs(angle_objective-actual_angle))
    return

MV = 4*1e-3
WP = 100
WV = .05
WR = .1
WRFL = 1e-8

num_sim = 15
MovementTime = .6
NumIteration = 60

X0= [70,70]
XN=[-10,100]

fig,ax = plt.subplots(figsize = (10,10))
start, end = longmovement_1()
compute_percent(start,end)


for n in range(num_sim):
    X,Y,_,_ = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=WRFL,Num_iter=NumIteration,starting_point=start,targets=end,Delay = 0.06,Activate_Noise=True,FF = False,motornoise_variance=MV)
    
    plt.plot(X,Y,color =  "#24C7C7",linewidth = 1)
    X,Y,_,_ = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=WRFL,Num_iter=NumIteration,starting_point=start,targets=end,Delay = 0.06,Activate_Noise=True,FF = False,motornoise_variance=MV, wp = WC,taupath = TAU,percent = PERCENT)
    
    plt.plot(X,Y,color = "#0072B2",linewidth = 1)
plt.plot(np.linspace(start[0],end[0],60),np.linspace(start[1],end[1],60),color = "grey",linestyle = "--")



st,tg = start,end
circle = plt.Circle((st[0],st[1]), 1.5, edgecolor='grey',facecolor = "grey", linewidth=3)
ax.add_patch(circle)
square = plt.Rectangle((tg[0]-1.5,tg[1]-1.5), 3,3, edgecolor='grey',facecolor = "grey", linewidth=3)
ax.add_patch(square)

start, end = longmovement_2()
compute_percent(start,end)


for n in range(num_sim):
    X,Y,_,_ = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=WRFL,Num_iter=NumIteration,starting_point=start,targets=end,Delay = 0.06,Activate_Noise=True,FF = False,motornoise_variance=MV)
    plt.plot(X,Y,color =  "#24C7C7",linewidth = 1)
    X,Y,_,_ = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=WRFL,Num_iter=NumIteration,starting_point=start,targets=end,Delay = 0.06,Activate_Noise=True,FF = False,motornoise_variance=MV, wp = WC,taupath = TAU,percent = PERCENT)
    plt.plot(X,Y,color = "#0072B2",linewidth = 1)
plt.plot(np.linspace(start[0],end[0],60),np.linspace(start[1],end[1],60),color = "grey",linestyle = "--")
delete_axis(ax)
plt.axis("equal")
st,tg = start,end
circle = plt.Circle((st[0],st[1]), 1.5, edgecolor='grey',facecolor = "grey", linewidth=3)
ax.add_patch(circle)
square = plt.Rectangle((tg[0]-1.5,tg[1]-1.5), 3,3, edgecolor='grey',facecolor = "grey", linewidth=3)
ax.add_patch(square)
delete_ticks(ax)

plt.savefig("ConstraintVariability.svg",dpi = 200)



plt.show()
# Out:
# 55.52842654658859
# 42.10495691800605

# %%
fig= plt.figure(figsize = (8,21))
gs = gridspec.GridSpec(7, 2)
ax1 = fig.add_subplot(gs[0,:]) 
ax2 = fig.add_subplot(gs[1,0])  
ax3 = fig.add_subplot(gs[1,1])  
ax4 = fig.add_subplot(gs[2,:])
ax4b = fig.add_subplot(gs[3,:])
ax5 = fig.add_subplot(gs[4,0])
ax6 = fig.add_subplot(gs[4,1])
ax7 = fig.add_subplot(gs[5,:])
ax8 = fig.add_subplot(gs[6,:])
MV = 0
WP = 100
WV = .05
WR = .1
WRFL = 1e-8
WC = .01
TAU = .03
PERCENT = .7
NUM_SIM = 100
MovementTime = .6
NumIteration = 60
Time = np.linspace(0,MovementTime,NumIteration)*1000
Cost_value = np.zeros((NUM_SIM,2))
Commands = np.zeros((NUM_SIM,2,6,NumIteration))
def ToCartesian(s,e):
    X = np.cos(s + e) * 33 + np.cos(s) * 30
    Y = np.sin(s + e) * 33 + np.sin(s) * 30

    return X, Y
def compute_percent(x0,xf):
    x0,xf = np.array(x0),np.array(xf)
    ts,te= compute_angles_from_cartesian(xf[0],xf[1])
    ts0,te0 = compute_angles_from_cartesian(x0[0],x0[1])
    te_incr,ts_incr = (te0 + .001*(te-te0)),(ts0 + .001*(ts-ts0))
    x_incr,y_incr = ToCartesian(ts_incr,te_incr)
    angle_objective = np.arctan2(xf[1]-x0[1],xf[0]-x0[0])*180/pi
    actual_angle = np.arctan2(y_incr-x0[1],x_incr-x0[0])*180/pi
    print(abs(angle_objective-actual_angle))
    return
Velocities = np.zeros((NUM_SIM,2,2,2,NumIteration))

def Cost_function(x,u,tg = [0,0] ):
    target1,target2 = compute_angles_from_cartesian(tg[0],tg[1])
    thetas,thetae,omegas,omegae = x[-1,:4]
    return WP*(thetas-target1)**2 + WP*(thetae-target2)**2 + WV*(omegas**2+omegae**2)+ np.sum(u*u) *WR * MovementTime/NumIteration



X0= [70,70]
XN=[-10,100]

start, end = longmovement_1()


for n in range(NUM_SIM):
    X,Y,x,u = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=WRFL,Num_iter=NumIteration,starting_point=start,targets=end,Delay = 0.06,Activate_Noise=True,FF = False,motornoise_variance=MV)
    Velocities[n,0,0] = x[:,2:4].T
    if n < 15: ax1.plot(X,Y,color =  "#24C7C7",linewidth = 1)
    Cost_value[n,0]= Cost_function(x,u,tg = end)
    Commands[n,0,:,1:] = u.T
    X,Y,x,u = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=WRFL,Num_iter=NumIteration,starting_point=start,targets=end,Delay = 0.06,Activate_Noise=True,FF = False,motornoise_variance=MV, wp = WC,taupath = TAU,percent = PERCENT)
    Velocities[n,1,0] = x[:,2:4].T
    if n < 15: ax1.plot(X,Y,color = "#0072B2",linewidth = 1)
    Commands[n,1,:,1:] = u.T
    Cost_value[n,1]= Cost_function(x,u,tg = end)

st,tg = start,end
circle = plt.Circle((st[0],st[1]), 1.5, edgecolor='grey',facecolor = "grey", linewidth=3)
ax1.add_patch(circle)
square = plt.Rectangle((tg[0]-1.5,tg[1]-1.5), 3,3, edgecolor='grey',facecolor = "grey", linewidth=3)
ax1.add_patch(square)
mean_command = np.mean(Commands,axis = 0)
for n in range(2):
    ax7.plot(Time,np.sum(mean_command[n]*mean_command[n],axis = 0),color = ["#24C7C7","#0072B2"][n],label = ["Without Constraint","With Constraint"][n])
        
    for k in range(6):
       ax8.plot(Time,mean_command[n,k]*mean_command[n,k],color = ["#24C7C7","#0072B2"][n],label = ["Without Constraint","With Constraint"][n])



start, end = longmovement_2()


for n in range(NUM_SIM):
    X,Y,x,u = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=WRFL,Num_iter=NumIteration,starting_point=start,targets=end,Delay = 0.06,Activate_Noise=True,FF = False,motornoise_variance=MV)
    Velocities[n,0,1] = x[:,2:4].T
    if n < 15:
        ax1.plot(X,Y,color =  "#24C7C7",linewidth = 1)
    Cost_value[n,0]= Cost_function(x,u,tg = end)
    X,Y,x,u = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=WRFL,Num_iter=NumIteration,starting_point=start,targets=end,Delay = 0.06,Activate_Noise=True,FF = False,motornoise_variance=MV, wp = WC,taupath = TAU,percent = PERCENT)
    Velocities[n,1,1] = x[:,2:4].T
    if n < 15:
        ax1.plot(X,Y,color = "#0072B2",linewidth = 1)
    Cost_value[n,1]= Cost_function(x,u,tg = end)

delete_axis(ax1)
ax1.set_aspect("equal")
st,tg = start,end
circle = plt.Circle((st[0],st[1]), 1.5, edgecolor='grey',facecolor = "grey", linewidth=3)
ax1.add_patch(circle)
square = plt.Rectangle((tg[0]-1.5,tg[1]-1.5), 3,3, edgecolor='grey',facecolor = "grey", linewidth=3)
ax1.add_patch(square)
delete_ticks(ax1)

mean_vel = np.mean(Velocities,axis = 0)*180/pi

colors = ["#24C7C7","#0072B2"]
linestyle = ["-","--"]
axis = [ax2,ax3]
for movement in range(2):
    for controller in range(2):
        for joint in range(2):
            axis[movement].plot(np.linspace(0,MovementTime*1000,NumIteration), mean_vel[controller,movement,joint], color=colors[controller],linestyle = linestyle[joint])
            std_vel = np.std(Velocities[:,controller,movement,joint],axis = 0)*180/pi
            axis[movement].fill_between(np.linspace(0,MovementTime*1000,NumIteration), mean_vel[controller,movement,joint] - std_vel, mean_vel[controller,movement,joint] + std_vel, color=colors[controller], alpha=0.3)
    delete_axis(axis[movement],sides = ["top","right"])
    axis[movement].set_xticks([0,100,200,300,400,500,600],labels = [0,"","","","","",600],fontsize = 20)
    axis[movement].set_yticks([-360,-270,-180,-90,0,90,180,270,360],labels = [-360,-270,-180,-90,0,90,180,270,360],fontsize = 20)
    axis[movement].legend(fontsize = 15)
    axis[movement].plot(Time,np.zeros(len(Time)),color = "black")

box = ax5.boxplot(Cost_value, patch_artist=True,
    medianprops=dict(color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),showfliers=False)

for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)


start, end = longmovement_1()

colors_range = get_colors_from_colormap(5,"plasma")
for idx,wc in enumerate(np.array([0,1e-3,2e-3,5e-3,1e-2])):
    Traj = np.zeros((NUM_SIM,2,NumIteration))
    for n in range(NUM_SIM):
        X,Y,x,u = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=WRFL,Num_iter=NumIteration,starting_point=start,targets=end,Delay = 0.06,Activate_Noise=True,FF = False,motornoise_variance=MV, wp = wc,taupath = TAU,percent = PERCENT)
        Traj[n] = np.array([X,Y])
    Traj = np.mean(Traj,axis = 0)
    ax4.plot(Traj[0],Traj[1],color = colors_range[idx],linewidth = 4)



st,tg = start,end
circle = plt.Circle((st[0],st[1]), 1.5, edgecolor='grey',facecolor = "grey", linewidth=3)
ax4.add_patch(circle)
square = plt.Rectangle((tg[0]-1.5,tg[1]-1.5), 3,3, edgecolor='grey',facecolor = "grey", linewidth=3)
ax4.add_patch(square)
delete_ticks(ax4)
delete_axis(ax4)
ax4.set_aspect("equal")

start, end = longmovement_2()

colors_range = get_colors_from_colormap(5,"plasma")
for idx,wc in enumerate(np.array([0,1e-3,2e-3,5e-3,1e-2])):
    Traj = np.zeros((NUM_SIM,2,NumIteration))
    for n in range(NUM_SIM):
        X,Y,x,u = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=WRFL,Num_iter=NumIteration,starting_point=start,targets=end,Delay = 0.06,Activate_Noise=True,FF = False,motornoise_variance=MV, wp = wc,taupath = TAU,percent = PERCENT)
        Traj[n] = np.array([X,Y])
    Traj = np.mean(Traj,axis = 0)
    ax4b.plot(Traj[0],Traj[1],color = colors_range[idx],linewidth = 4)



st,tg = start,end
circle = plt.Circle((st[0],st[1]), 1.5, edgecolor='grey',facecolor = "grey", linewidth=3)
ax4b.add_patch(circle)
square = plt.Rectangle((tg[0]-1.5,tg[1]-1.5), 3,3, edgecolor='grey',facecolor = "grey", linewidth=3)
ax4b.add_patch(square)
delete_ticks(ax4b)
delete_axis(ax4b)
ax4b.set_aspect("equal")

box = ax6.boxplot(Cost_value, patch_artist=True,
    medianprops=dict(color='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),showfliers=False)

for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)





plt.savefig("PC.svg",dpi = 200)



plt.show()
# Out:
# C:\Users\thyriona\AppData\Local\Temp\ipykernel_14624\211662501.py:120: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axis[movement].legend(fontsize = 15)
# C:\Users\thyriona\AppData\Local\Temp\ipykernel_14624\211662501.py:120: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axis[movement].legend(fontsize = 15)

# %%
import os
os.chdir('..')

from Controllers.FL import *
from Controllers.ILQG import *
from Controllers.LQGControllers import *
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib import gridspec

MN = 5e-4
WP = 20000
WV = 1
WR = .5

def Cost_function(x,u,w1 = WP,w2 = WV,r = WR,tg = [0,0] ):
    target1,target2 = compute_angles_from_cartesian(tg[0],tg[1])
    thetas,thetae,omegas,omegae = x[-1,:4]
    
    return w1*(thetas-target1)**2 + w1*(thetae-target2)**2 + w2*(omegas**2+omegae**2)+ np.sum(u*u) * r



def sensitivity_analysis(wp,wv,wr,wrfl,num_sim):

    MovementTime = .6
    NumIteration = 60
    Cost_value = np.zeros((num_sim,3))

    st = [0,45]
    tg = [0,60]
    ffpow = 4e-4

    for i in range(num_sim):
        xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,wp,wv,wr,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False,FF =  True,ff_power=ffpow)
        xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=wp,w2=wp,w3=wv,w4=wv,r=wrfl,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True,FF = True,ff_power=ffpow)
        xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = wp,w2 = wp,w3 = wv,w4 = wv, Duration=MovementTime,r1 = wr,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True,FF = True,ff_power=ffpow)
        
        Cost_value[i]=[Cost_function(zilqg,uILQG,wp,wv,wr,tg = tg),Cost_function(xfl,uFL,wp,wv,wr,tg = tg),Cost_function(z.T,uDLQG,wp,wv,wr,tg = tg)]

        #xILQG,yILQG,zilqg,uILQG=simulate_ILQG(MovementTime,WP,WV,WR,tg,st,NumIteration,delay = 0.06,Noise=True,print_iterations=False,FF =  False, ff_power=0)
        #xFL,yFL,xfl,uFL = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=1e-8,Num_iter=NumIteration,starting_point=st,targets=tg,Delay = 0.06,Activate_Noise=True,FF = False,ff_power=0)
        #xLQG,yLQG,uDLQG,z=DLQG_6Muscles(w1 = WP,w2 = WP,w3 = WV,w4 = WV, Duration=MovementTime,r1 = WR,Num_iter=NumIteration,starting_point=st,targets=tg,plot = False,Delay = 0.06,Activate_Noise=True,FF = False,ff_power=0)
        #Cost_value_NOFF[i]=[Cost_function(zilqg,uILQG,tg = tg),Cost_function(xfl,uFL,tg = tg),Cost_function(z.T,uDLQG,tg = tg)]
    
    return Cost_value

fig,ax = plt.subplots(3,figsize = (8,8)) 
colors = ["#009E73","#0072B2","#E69F00"]
legend = ["ILQG","FL","DLQG"]       
delete_axis(ax[1],sides =  ["top","right"])

NUM_SIM = 100
NUM_DISCRETIZATION = 20
wp_values = np.linspace(2000,200000,NUM_DISCRETIZATION)
wv_values = np.linspace(0.1,10,NUM_DISCRETIZATION)
wr_values = np.linspace(0.05,5,NUM_DISCRETIZATION)

Average_Cost = np.zeros((NUM_DISCRETIZATION,3))
for i in range(NUM_DISCRETIZATION):
    Cost_value = sensitivity_analysis(wp_values[i],WV,WR,1e-8,NUM_SIM)
    Average_Cost[i] = np.mean(Cost_value,axis = 0)
    print("Done with iteration ",i)

ax[0].plot(wp_values,Average_Cost[:,0],color = colors[0],label = legend[0])
ax[0].plot(wp_values,Average_Cost[:,1],color = colors[1],label = legend[1])
ax[0].plot(wp_values,Average_Cost[:,2],color = colors[2],label = legend[2])
ax[0].set_yscale("log")

Average_Cost = np.zeros((NUM_DISCRETIZATION,3))
for i in range(NUM_DISCRETIZATION):
    Cost_value = sensitivity_analysis(WP,wv_values[i],WR,1e-8,NUM_SIM)
    Average_Cost[i] = np.mean(Cost_value,axis = 0)
    print("Done with iteration ",i)

ax[1].plot(wv_values,Average_Cost[:,0],color = colors[0],label = legend[0])
ax[1].plot(wv_values,Average_Cost[:,1],color = colors[1],label = legend[1])
ax[1].plot(wv_values,Average_Cost[:,2],color = colors[2],label = legend[2])
ax[1].set_yscale("log")

Average_Cost = np.zeros((NUM_DISCRETIZATION,3))
for i in range(NUM_DISCRETIZATION):
    Cost_value = sensitivity_analysis(WP,WV,wr_values[i],1e-8,NUM_SIM)
    Average_Cost[i] = np.mean(Cost_value,axis = 0)
    print("Done with iteration ",i)

ax[2].plot(wr_values,Average_Cost[:,0],color = colors[0],label = legend[0])
ax[2].plot(wr_values,Average_Cost[:,1],color = colors[1],label = legend[1])
ax[2].plot(wr_values,Average_Cost[:,2],color = colors[2],label = legend[2])
ax[2].set_yscale("log")

plt.savefig("Sensitivity_Analysis.svg",dpi = 300)
#plt.savefig("FFvsNOFF.svg",dpi = 300)
# Out:
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:469: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[k] = Q[k] + A[k].T @ S[k + 1] @ A[k] - G.T @ Hinv @ G
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:470: ComplexWarning: Casting complex values to real discards the imaginary part
#   sbold[k] = qbold[k] + A[k].T @ sbold[k + 1] - G.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:471: ComplexWarning: Casting complex values to real discards the imaginary part
#   s[k] = q[k] + s[k + 1] + 0.5 * temp3 - 0.5 * gbold.T @ Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:473: ComplexWarning: Casting complex values to real discards the imaginary part
#   l[k] = -Hinv @ gbold
# d:\thyriona\Desktop\Codes\My_research\WP1\Controllers\ILQG.py:474: ComplexWarning: Casting complex values to real discards the imaginary part
#   L[k] = -Hinv @ G
# Done with iteration  0
# ...

# %%
WC = .0006
TAU = .07
PERCENT = .7


MV = 1e-3
WP = 100
WV = .05
WR = .1
WRFL = 1e-8

num_sim = 6
MovementTime = .6
NumIteration = 60

X0= [70,70]
XN=[-10,100]

fig,ax = plt.subplots(figsize = (10,10))
start, end = longmovement_1()
colors = get_colors_from_colormap(num_sim,"viridis")


for n in range(num_sim):
    start = np.array([np.random.uniform(-20,20),np.random.uniform(30,50)])
    end = np.array([np.random.uniform(-20,20),np.random.uniform(30,50)])
    print(np.linalg.norm(np.array(start)-np.array(end))/10)
    WCmodif = WC 
    X,Y,_,_ = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=WRFL,Num_iter=NumIteration,starting_point=start,targets=end,Delay = 0.06,Activate_Noise=False,FF = False,motornoise_variance=MV, wp = WCmodif,taupath = TAU,percent = PERCENT)
    
    plt.scatter([start[0]],[start[1]],marker = "o",s = 50,color = "grey")
    plt.plot(X,Y,color = colors[n],linewidth = 1)
    plt.plot(np.linspace(start[0],end[0],60),np.linspace(start[1],end[1],60),color = "grey",linestyle = "--")

    X,Y,_,_ = simulate_FL(Duration=MovementTime,w1=WP,w2=WP,w3=WV,w4=WV,r=WRFL,Num_iter=NumIteration,starting_point=start,targets=end,Delay = 0.06,Activate_Noise=False,FF = False,motornoise_variance=MV, wp = 0,taupath = TAU,percent = PERCENT)
    plt.plot(X,Y,color = colors[n],linewidth = 1,linestyle = "--")
plt.axis("equal")

plt.show()
# Out:
# 1.4985202738617838
# 1.509806548652342
# 2.801094128958906
# 1.0307137939122473
# 1.558315899691433
# 1.980596424944246
