# %%
from ILQGMuscle import *
start = np.array([0,40])
d = 12

    # Plot result
plt.figure(figsize=(10, 16))
for angles in np.linspace(0,2*pi,9)[:-1]:
    end = start + np.array([d*cos(angles),d*sin(angles)])
    
    x =ILQG(K = 30,w1 = 1e4 , w2 = 1, r1 = 1e-4,targets = end,start = start)

# %%
from NMPC import *
end = ToCartesian(np.array([-10/180*pi,100/180*pi]))
start = ToCartesian(np.array([70/180*pi,70/180*pi]))
print(MPC42(.6,start,end,1e4,1,1e-5*np.ones(6),30,.02,30,plot = False))

# %%
from ILQGMuscle import *
end = ToCartesian(np.array([-10/180*pi,100/180*pi]))
start = ToCartesian(np.array([70/180*pi,70/180*pi]))
K = 60
plt.figure(figsize = (10,10))
MPC42(.6,start,end,1e4,1,1e-5*np.ones(6),K,.6/K,K,plot = True)
_,_,_,x =ILQG(Duration = .6,K = K,w1 = 1e4, w2 = 1, r1 = 1e-4,targets = end,start = start,mpc = False)
#_,_,_,x =ILQG(Duration = .6,K = K,w1 = 1e4, w2 = 1, r1 = 1e-4,targets = end,start = start,mpc = True)
plt.show()
plt.plot(np.linspace(0,.6,K),x[:,2])
plt.plot(np.linspace(0,.6,K),x[:,3],linestyle = "--")
plt.plot(np.linspace(0,.6,K),np.zeros(K))

# %%
from ILQGMuscle import *
end = ToCartesian(np.array([30/180*pi,50/180*pi]))
start = ToCartesian(np.array([70/180*pi,110/180*pi]))
    

K = 60
plt.figure(figsize = (10,10))
MPC42(.6,start,end,1e4,1,1e-5*np.ones(6),K,.6/K,K,plot = True)
_,_,_,x =ILQG(Duration = .6,K = K,w1 = 1e4, w2 = 1, r1 = 1e-4,targets = end,start = start,mpc = False)
#_,_,_,x =ILQG(Duration = .6,K = K,w1 = 1e4, w2 = 1, r1 = 1e-4,targets = end,start = start,mpc = True)
plt.show()
plt.plot(np.linspace(0,.6,K),x[:,2])
plt.plot(np.linspace(0,.6,K),x[:,3],linestyle = "--")
plt.plot(np.linspace(0,.6,K),np.zeros(K))
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# ### Iteration  0  ###
# ### Iteration  1  ###
# ### Iteration  2  ###
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:355: ComplexWarning: Casting complex values to real discards the imaginary part
#   S[k] = Q[k] + A[k].T@S[k+1]@A[k]-G.T@Hinv@G
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:356: ComplexWarning: Casting complex values to real discards the imaginary part
#   sbold[k] = qbold[k]+A[k].T@sbold[k+1]-G.T@Hinv@gbold
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:357: ComplexWarning: Casting complex values to real discards the imaginary part
#   s[k] = q[k] + s[k+1] + 0.5*temp3 - .5*gbold.T@Hinv@gbold
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:359: ComplexWarning: Casting complex values to real discards the imaginary part
#   l[k] = -Hinv@gbold
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:360: ComplexWarning: Casting complex values to real discards the imaginary part
#   L[k] = -Hinv@G
# ### Iteration  3  ###
# ### Iteration  4  ###
# ### Iteration  5  ###
# ### Iteration  6  ###
# ### Iteration  7  ###
# ### Iteration  8  ###
# ### Iteration  9  ###
# ### Iteration  10  ###
# ### Iteration  11  ###
# ### Iteration  12  ###
# ### Iteration  13  ###
# ### Iteration  14  ###
# ### Iteration  15  ###
# ### Iteration  16  ###
# ### Iteration  17  ###
# ### Iteration  18  ###
# ### Iteration  19  ###
# ### Iteration  20  ###
# ### Iteration  21  ###
# ### Iteration  22  ###
# ### Iteration  23  ###
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:6: RuntimeWarning: overflow encountered in scalar multiply
#   C = np.array([-x[3]*(2*x[2]+x[3])*a2*np.sin(x[1]),x[2]*x[2]*a2*np.sin(x[1])])
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:25: RuntimeWarning: invalid value encountered in matmul
#   theta = Minv@(torque-Bdyn@x[2:4]-C)
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:19: RuntimeWarning: overflow encountered in square
#   fl = np.exp(-(((l-lrest)/lrest)/.5)**2)
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:47: RuntimeWarning: overflow encountered in scalar multiply
#   Cdot = np.array([-x[3]*(2*x[2]+x[3])*a2*np.cos(x[1])*x[3],x[2]*x[2]*a2*np.cos(x[1])*x[3]])
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:69: RuntimeWarning: overflow encountered in matmul
#   return dMinv@(torque-Bdyn@x[2:4]-C)+Minv@(torquedot-Cdot)
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:69: RuntimeWarning: invalid value encountered in add
#   return dMinv@(torque-Bdyn@x[2:4]-C)+Minv@(torquedot-Cdot)
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:46: RuntimeWarning: overflow encountered in scalar multiply
#   C = np.array([-x[3]*(2*x[2]+x[3])*a2*np.sin(x[1]),x[2]*x[2]*a2*np.sin(x[1])])
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:69: RuntimeWarning: invalid value encountered in matmul
#   return dMinv@(torque-Bdyn@x[2:4]-C)+Minv@(torquedot-Cdot)
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:85: RuntimeWarning: overflow encountered in square
#   dfv =(-dv*(vmax+.3*v)-(vmax-v)*.3*dv)/(vmax+.3*v)**2
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:106: RuntimeWarning: overflow encountered in square
#   dfv =(-dv*(vmax+.3*v)-(vmax-v)*.3*dv)/(vmax+.3*v)**2
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:39: RuntimeWarning: overflow encountered in square
#   dfl = np.exp(-(((l-lrest)/lrest)/.5)**2)*(-2*l+2*lrest)/(.5*lrest)**2*(-A@np.array([1,0]))
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:61: RuntimeWarning: overflow encountered in square
#   fl = np.exp(-(((l-lrest)/lrest)/.5)**2)
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:64: RuntimeWarning: overflow encountered in square
#   dfl = np.exp(-(((l-lrest)/lrest)/.5)**2)*(-2*l+2*lrest)/(.5*lrest)**2*(-A@np.array([0,1]))
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:84: RuntimeWarning: overflow encountered in square
#   fl = np.exp(-(((l-lrest)/lrest)/.5)**2)
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:105: RuntimeWarning: overflow encountered in square
#   fl = np.exp(-(((l-lrest)/lrest)/.5)**2)
# d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:123: RuntimeWarning: overflow encountered in square
#   fl = np.exp(-(((l-lrest)/lrest)/.5)**2)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[1], line 9
#       7 plt.figure(figsize = (10,10))
#       8 MPC42(.6,start,end,1e4,1,1e-5*np.ones(6),K,.6/K,K,plot = True)
# ----> 9 _,_,_,x =ILQG(Duration = .6,K = K,w1 = 1e4, w2 = 1, r1 = 1e-4,targets = end,start = start,mpc = False)
#      10 #_,_,_,x =ILQG(Duration = .6,K = K,w1 = 1e4, w2 = 1, r1 = 1e-4,targets = end,start = start,mpc = True)
#      11 plt.show()
#
# File d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:430, in ILQG(Duration, w1, w2, r1, targets, K, start, plot, Noise, Delay, FF, Side, Variance, mpc)
#     427     break
#     429 A,B,q,qbold,r,Q,R = step2(x,u,Duration,w1,w2,r1,np.array([obj1,obj2]))
# --> 430 l,L = step3(A,B,C,cbold,q,qbold,r,Q,R,p)
#     431 u_incr = step4(l,L,K,A,B)
#     432 u += u_incr
#
# File d:\thyriona\Desktop\Codes\FL\PhD\ILQGMuscle.py:339, in step3(A, B, C, cbold, q, qbold, r, Q, R, p)
#     336         G = B[k].T@S[k+1]@A[k]
#     337         H = R[k] + B[k].T@S[k+1]@B[k]+temp2
# --> 339         eigenvalues, eigenvectors = np.linalg.eig(H)
#     342 #
#     343 #
#     344 # Verify decomposition: A = V Λ V⁻¹
#     345         V = np.diag(eigenvalues)  # Create diagonal matrix
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\linalg\_linalg.py:1482, in eig(a)
#    1480 _assert_stacked_2d(a)
#    1481 _assert_stacked_square(a)
# -> 1482 _assert_finite(a)
#    1483 t, result_t = _commonType(a)
#    1485 signature = 'D->DD' if isComplexType(t) else 'd->DD'
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\linalg\_linalg.py:207, in _assert_finite(*arrays)
#     205 for a in arrays:
#     206     if not isfinite(a).all():
# --> 207         raise LinAlgError("Array must not contain infs or NaNs")
#
# LinAlgError: Array must not contain infs or NaNs

# %%
from ILQGMuscle import *
end = ToCartesian(np.array([30/180*pi,50/180*pi]))
start = ToCartesian(np.array([70/180*pi,110/180*pi]))
    

K = 60
plt.figure(figsize = (10,10))
MPC42(.6,start,end,1e4,1,1e-5*np.ones(6),K,.6/K,K,plot = True)
_,_,_,x =ILQG(Duration = .6,K = K,w1 = 1e4, w2 = 1, r1 = 1e-4,targets = end,start = start,mpc = True)
#_,_,_,x =ILQG(Duration = .6,K = K,w1 = 1e4, w2 = 1, r1 = 1e-4,targets = end,start = start,mpc = True)
plt.show()
plt.plot(np.linspace(0,.6,K),x[:,2])
plt.plot(np.linspace(0,.6,K),x[:,3],linestyle = "--")
plt.plot(np.linspace(0,.6,K),np.zeros(K))
# Out:
# ### Iteration  0  ###
# ### Iteration  1  ###
# ### Iteration  2  ###
# ### Iteration  3  ###
# ### Iteration  4  ###
# ### Iteration  5  ###
# ### Iteration  6  ###
# ### Iteration  7  ###
# ### Iteration  8  ###
# ### Iteration  9  ###
# ### Iteration  10  ###
# ### Iteration  11  ###
# ### Iteration  12  ###
# ### Iteration  13  ###
# ### Iteration  14  ###
# ### Iteration  15  ###
# ### Iteration  16  ###
# ### Iteration  17  ###
# ### Iteration  18  ###
# ### Iteration  19  ###
# ### Iteration  20  ###
# ### Iteration  21  ###
# ### Iteration  22  ###
# ### Iteration  23  ###
# ### Iteration  24  ###
# ### Iteration  25  ###
# ### Iteration  26  ###
# ### Iteration  27  ###
# ### Iteration  28  ###
# ### Iteration  29  ###
# ### Iteration  30  ###
# ### Iteration  31  ###
# ### Iteration  32  ###
# ### Iteration  33  ###
# ### Iteration  34  ###
# ### Iteration  35  ###
# ### Iteration  36  ###
# ### Iteration  37  ###
# ### Iteration  38  ###
# ### Iteration  39  ###
# ### Iteration  40  ###
# ### Iteration  41  ###
# ### Iteration  42  ###
# ### Iteration  43  ###
# ### Iteration  44  ###
# ### Iteration  45  ###
# ### Iteration  46  ###
# ### Iteration  47  ###
# ### Iteration  48  ###
# ### Iteration  49  ###
# ### Iteration  50  ###
# ### Iteration  51  ###
# ### Iteration  52  ###
# ### Iteration  53  ###
# ### Iteration  54  ###
# ### Iteration  55  ###
# ### Iteration  56  ###
# ### Iteration  57  ###
# ### Iteration  58  ###
# ### Iteration  59  ###
# ### Iteration  60  ###
# ### Iteration  61  ###
# ### Iteration  62  ###
# ### Iteration  63  ###
# ### Iteration  64  ###
# ### Iteration  65  ###
# ### Iteration  66  ###
# ### Iteration  67  ###
# ### Iteration  68  ###
# ### Iteration  69  ###
# ### A Solution has been found ###
# [-22.7393957  -22.7393957  -22.7393957  -22.72853144 -22.6984484
#  -22.64285839 -22.55711333 -22.43782507 -22.28254281 -22.0894883
#  -21.85734401 -21.58508684 -21.27185983 -20.91687475 -20.51933971
#  -20.07840696 -19.59313711 -19.06247699 -18.48524917 -17.86015176
#  -17.18576755 -16.46058207 -15.68301026 -14.85143168 -13.96423406
#  -13.01986518 -12.01689263 -10.95407086  -9.83041456  -8.64527683
#   -7.39843048  -6.09014971  -4.72128964  -3.29336046  -1.80859286
#   -0.26999174   1.31862449   2.95260096   4.62644036   6.33381334
#    8.06758307   9.8198401   11.58194265  13.34455613  15.09768617
#   16.8306998   18.53233156  20.19067436  21.79315892  23.32653087
#   24.77684009  26.12946344  27.36918883  28.48039727  29.44739085
#   30.25493224  30.88908916  31.33851746  31.59635898  31.71521633] [28.19077862 28.19077862 28.19077862 28.1979858  28.21832024 28.25660122
#  28.31671692 28.40177401 28.51422567 28.65597885 28.82848194 29.03279505
#  29.2696449  29.53946645 29.84243317 30.17847768 30.54730404 30.94839339
#  31.38100371 31.84416519 32.33667202 32.85707196 33.40365476 33.97444081
#  34.56717137 35.1793021  35.80800133 36.45015498 37.10237973 37.76104601
#  38.42231207 39.08216997 39.73650366 40.38115852 41.0120207  41.62510364
#  42.21663799 42.78316021 43.32159446 43.8293221  44.30423338 44.74475701
#  45.14986477 45.51905088 45.85228896 46.1499724  46.4128476  46.6419519
#  46.83856918 47.00421505 47.14065822 47.2499739  47.33460955 47.39742662
#  47.44166825 47.47079254 47.48812004 47.49629674 47.49668725 47.49638686]
